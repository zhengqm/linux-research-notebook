# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
commits = pd.read_pickle("commits.pkl")

# %%
def isDRM(f):
    fs = f.split(',')
    for f in fs:
        if 'Documentation/gpu/' in f:
            return True
        if 'drivers/gpu/vga/' in f:
            return True
        parts = f.split('/')
        if 'drivers/gpu/drm' in f and len(parts) == 4:
            return True
        if 'include/drm/drm' in f:
            return True
        if 'include/uapi/drm/drm' in f:
            return True
        if 'include/linux/vga' in f:
            return True
    return False

def isi915(f):
    return "drivers/gpu/drm/i915/" in f or "include/drm/i915" in f or "include/uapi/drm/i915_drm.h" in f or "Documentation/gpu/i915.rst" in f

def isi9152(f):
    return "i915" in f

# %%
commits['isDRM'] = commits.files.map(isDRM)

# %%
commits['isi915'] = commits.files.map(isi915)

# %%
commits['isi9152'] = commits.files.map(isi9152)

# %%
selected = commits[commits.isi915]

# %%
commits[commits.isi915 != commits.isi9152]
# Out:
#                                           hexsha         authored_datetime  \
# 15098   6c5a266029cc9b036643d08c2f9340d09ee03708 2017-07-18 17:05:06+00:00
# 61969   c461265679ce934c26339897bba2ff5c2120262f 2016-12-07 13:58:19+00:00
# 111442  bb03ed216370cb021f377f923471e56d1de3ff5d 2016-04-21 14:39:17+00:00
# 115950  bfa5fb14fb9e698ae2d9429a82ef0ab67a17df37 2016-03-29 13:03:06+00:00
# 116855  97cc2ed27e5a168cf423f67c3bc7c6cc41d12f82 2016-03-29 16:48:07+00:00
# 116888  faafd03d23c913633d2ef7e6ffebdce01b164409 2016-03-29 10:29:24+00:00
# 117311  d745f5e7b8b2961f68b0b9093a0f914a8a83c2ae 2016-03-21 13:41:58+00:00
# 120549  1a414f48d7ccb197b61c18888b72327c98171844 2016-03-10 14:49:35+00:00
# 133034  bed2e98e1f4db8b827df507abc30be7b11b0613d 2016-01-20 14:00:26+00:00
# 140663  e2dc7d7d8ed3019f72855af1c3dcda3fb456b488 2015-12-01 11:39:38+00:00
# 148493  78dd5e21b075053e67194ea8f496439bebc52728 2015-10-28 11:26:48+00:00
# 161447  6869de380e8c11c31b608bb2502dcacd634eda13 2015-09-02 10:24:55+00:00
# 161449  45c053df5bdc4843cf19b920db6ab819ddc27ff7 2015-08-19 08:48:57+00:00
# 171000  033ea349a7cd1aa15357cd6575de35188fc85b9a 2015-07-16 08:39:24+00:00
# 177911  692af901df615b7783caaccdb287cddf2d7f6059 2015-06-10 10:15:27+00:00
# 183136  98d8fc6c5d3652e91c61d78941e0fa6f94771d67 2015-05-19 14:29:30+00:00
# 186689  0a67352153505f3ef2cdd155bfcbf7e43186bd82 2015-05-05 01:05:48+00:00
# 187602  d4b7b13e19258a848da920502e27526f36c5a59d 2015-04-29 09:43:12+00:00
# 188626  f4c1a311d8dc55c90c39e9cf7b003254a769574d 2015-04-20 09:33:57+00:00
# 201637  89a93fea6182a71cedce9de1d901e4f379322cf3 2015-02-19 17:04:17+00:00
# 210269  d7055bd653e00ef40a07065d1c94380240314c48 2015-01-08 15:54:17+00:00
# 210270  926981ae3325257d0bffcf7ff7ba359edb4fd7e8 2015-01-08 15:54:16+00:00
# 210271  347de1f8625199d177caf7668cfa1c00717faedb 2015-01-08 15:54:15+00:00
# 249397  e4d9e513dedb5ac4e166c1053314fa935ddecc8c 2014-07-03 09:02:23+00:00
# 276684  4e76a8833fac8dc1735aa5be7d1b3c92c65e209e 2014-02-25 11:21:03+00:00
# 327801  99a2008d0b32d72dfc2a54e7be1eb698dd2e3bd6 2013-05-30 14:07:10+00:00
# 606665  3d25802e3ba7c82457b5c12bbfeefe391d8a333e 2008-07-01 19:32:52+00:00
# 607396  ea7b44c8e6baa1a4507f05ba2c0009ac21c3fe0b 2008-06-24 17:38:31+00:00
# 607763  d3adbc0c582b767ba1561ffa38313e905cc917ea 2008-06-20 02:12:56+00:00
# 611668  e948e99400b28af152414f15f8c8023ff2430b79 2008-05-07 02:27:53+00:00
# ...                                          ...                       ...
# 665031  21fa60ed4eab5b3b28d05930bb086615ecc191b1 2006-10-24 14:10:59+00:00
# 665032  2dbb232c4d6b6c89fc367f7566c7c87dd3b56cd7 2006-10-24 14:10:24+00:00
# 665033  376642cf2eb0f32d8502b0a2c4efd96a3f13a8b8 2006-10-24 14:09:35+00:00
# 665034  5b51694aff705c465ef5941a99073036f3e444d9 2006-10-24 14:08:23+00:00
# 665035  541f29aad766b6c7b911a7d900d952744369bf53 2006-10-24 13:38:54+00:00
# 665036  a6b54f3f5050c0cbc0c35dd48064846c6302706b 2006-10-24 13:37:43+00:00
# 665045  68815bad7239989d92f315c10d9ef65a11945a75 2006-10-24 12:28:51+00:00
# 672959  2f02cc3fb8960754a2a5df6a33f53528e0d830be 2006-09-21 18:19:34+00:00
# 672965  46acbf13fb280e69c5cafe7c837d5a27c6e380c3 2006-08-27 01:09:46+00:00
# 672973  78eca43d0391f59c3b1505bb7bd38ff45b650aab 2006-08-15 23:15:51+00:00
# 672975  c29b669caae4ed1630ef479e54bdde126a0378ec 2006-08-12 06:29:24+00:00
# 678217  702880f24373dfb31edb0bcd997ff924d07decc3 2006-06-24 07:07:34+00:00
# 685948  6e5fca53c72c95da92c092411c7ec81e926af632 2006-03-20 07:34:29+00:00
# 685960  e7f947b908921a661efcbc08ce42d7de67691b07 2006-03-19 09:28:19+00:00
# 687157  91e3738ebc6d858e784090382e02afeae5a93b08 2006-02-18 04:17:04+00:00
# 688731  de227f5f32775d86e5c780a7cffdd2e08574f7fb 2006-01-25 04:31:43+00:00
# 690308  7ff92053ddff48d9d7908a353bd85f893944463e 2006-01-10 04:52:17+00:00
# 692228  0d6aa60b4ac9689b750e35cd66f5d7c053aff0f4 2006-01-02 09:14:23+00:00
# 692238  a7a2cc315c8a5e51b08538d102ec3229c966ac87 2006-01-02 02:54:04+00:00
# 694074  792d2b9a12594522111fbe2a7f17460a4d7edff7 2005-11-11 12:30:27+00:00
# 694195  22eae947bf76e236ba972f2f11cfd1b083b736ad 2005-11-10 11:16:34+00:00
# 698215  b3a83639895a422b25f72eec0a5d1d88c3ac4e9e 2005-09-30 08:37:36+00:00
# 698448  b6ce156c415544f900e031890c78eba8bc92f9b3 2005-09-25 05:07:24+00:00
# 698450  b5e89ed53ed8d24f83ba1941c07382af00ed238e 2005-09-25 04:28:13+00:00
# 703345  cda173806644d2af22ffd9896eed8ef99b97d356 2005-07-10 07:31:26+00:00
# 703350  9c8da5ebbf6f87293cf8555182da271449889a69 2005-07-10 05:38:56+00:00
# 703354  f179bc77d09b9087bfc559d0368bba350342ac76 2005-07-10 02:46:19+00:00
# 703577  8ca7c1df08210fd35fccf1559837c92baaa4da8f 2005-07-07 11:51:26+00:00
# 703579  c94f70298529d99ac6e1ee7709f61eab00adeb39 2005-07-07 11:03:38+00:00
# 704962  bc54fd1ad3c5972be339a08528ab631326ed2b38 2005-06-23 12:46:46+00:00
#
#                            author_name                     author_email  \
# 15098                     Arvind Yadav        arvind.yadav.cs@gmail.com
# 61969                     Chris Wilson         chris@chris-wilson.co.uk
# 111442                    Takashi Iwai                    tiwai@suse.de
# 115950                    Takashi Iwai                    tiwai@suse.de
# 116855                    Takashi Iwai                    tiwai@suse.de
# 116888                    Takashi Iwai                    tiwai@suse.de
# 117311                    Takashi Iwai                    tiwai@suse.de
# 120549                    Takashi Iwai                    tiwai@suse.de
# 133034                    Takashi Iwai                    tiwai@suse.de
# 140663                    Takashi Iwai                    tiwai@suse.de
# 148493                    Takashi Iwai                    tiwai@suse.de
# 161447                    Takashi Iwai                    tiwai@suse.de
# 161449               David Henningsson  david.henningsson@canonical.com
# 171000               David Henningsson  david.henningsson@canonical.com
# 177911                    Takashi Iwai                    tiwai@suse.de
# 183136                    Mengdong Lin           mengdong.lin@intel.com
# 186689                         Lu, Han                 han.lu@intel.com
# 187602                    Mengdong Lin           mengdong.lin@intel.com
# 188626                    Mengdong Lin           mengdong.lin@intel.com
# 201637                    Takashi Iwai                    tiwai@suse.de
# 210269                       Imre Deak              imre.deak@intel.com
# 210270                       Imre Deak              imre.deak@intel.com
# 210271                       Imre Deak              imre.deak@intel.com
# 249397                    Mengdong Lin           mengdong.lin@intel.com
# 276684                    Takashi Iwai                    tiwai@suse.de
# 327801                   Wang Xingchao    xingchao.wang@linux.intel.com
# 606665                    Jesse Barnes         jbarnes@virtuousgeek.org
# 607396                         Jie Luo               clotho67@gmail.com
# 607763                     Zhenyu Wang          zhenyu.z.wang@intel.com
# 611668                   Keith Packard                keithp@keithp.com
# ...                                ...                              ...
# 665031  =?utf-8?q?Michel_D=C3=A4nzer?=      michel@tungstengraphics.com
# 665032  =?utf-8?q?Michel_D=C3=A4nzer?=      michel@tungstengraphics.com
# 665033  =?utf-8?q?Michel_D=C3=A4nzer?=      michel@tungstengraphics.com
# 665034  =?utf-8?q?Michel_D=C3=A4nzer?=      michel@tungstengraphics.com
# 665035  =?utf-8?q?Michel_D=C3=A4nzer?=      michel@tungstengraphics.com
# 665036  =?utf-8?q?Michel_D=C3=A4nzer?=      michel@tungstengraphics.com
# 665045  =?utf-8?q?Michel_D=C3=A4nzer?=      michel@tungstengraphics.com
# 672959                     Eric Anholt                  eric@anholt.net
# 672965                     Dave Airlie                 airlied@linux.ie
# 672973                   Andrew Morton                    akpm@osdl.org
# 672975                  Alan Hourihane       alanh@tungstengraphics.com
# 678217                     Dave Airlie                 airlied@linux.ie
# 685948                     Dave Airlie                 airlied@linux.ie
# 685960                     Dave Airlie                 airlied@linux.ie
# 687157                     Dave Airlie                 airlied@linux.ie
# 688731                     Dave Airlie         airlied@starflyer.(none)
# 690308               Christoph Hellwig                       hch@lst.de
# 692228                     Dave Airlie         airlied@starflyer.(none)
# 692238                     Dave Airlie         airlied@starflyer.(none)
# 694074                     Dave Airlie         airlied@starflyer.(none)
# 694195                     Dave Airlie         airlied@starflyer.(none)
# 698215                     Dave Airlie         airlied@starflyer.(none)
# 698448                     Dave Airlie         airlied@starflyer.(none)
# 698450                     Dave Airlie         airlied@starflyer.(none)
# 703345                     Dave Airlie         airlied@starflyer.(none)
# 703350                     Dave Airlie         airlied@starflyer.(none)
# 703354                     Dave Airlie         airlied@starflyer.(none)
# 703577                     Dave Airlie         airlied@starflyer.(none)
# 703579                     Dave Airlie         airlied@starflyer.(none)
# 704962                     Dave Airlie         airlied@starflyer.(none)
#
#               committed_datetime  committer_name  \
# 15098  2017-07-18 18:01:21+00:00    Takashi Iwai
# 61969  2016-12-08 16:34:13+00:00      Shuah Khan
# 111442 2016-04-26 08:11:11+00:00    Takashi Iwai
# 115950 2016-04-04 09:46:17+00:00    Takashi Iwai
# 116855 2016-03-29 16:48:07+00:00    Takashi Iwai
# 116888 2016-03-29 10:29:24+00:00    Takashi Iwai
# 117311 2016-03-28 07:38:40+00:00    Takashi Iwai
# 120549 2016-03-10 14:54:42+00:00    Takashi Iwai
# 133034 2016-01-20 14:00:26+00:00    Takashi Iwai
# 140663 2015-12-10 13:41:07+00:00    Takashi Iwai
# 148493 2015-10-28 11:37:29+00:00    Takashi Iwai
# 161447 2015-09-02 10:24:55+00:00    Takashi Iwai
# 161449 2015-09-02 10:23:55+00:00    Takashi Iwai
# 171000 2015-07-20 07:33:24+00:00    Takashi Iwai
# 177911 2015-06-10 10:15:27+00:00    Takashi Iwai
# 183136 2015-05-20 04:16:36+00:00    Takashi Iwai
# 186689 2015-05-05 12:44:36+00:00    Takashi Iwai
# 187602 2015-04-29 10:27:52+00:00    Takashi Iwai
# 188626 2015-04-20 15:27:55+00:00    Takashi Iwai
# 201637 2015-02-19 20:41:25+00:00    Takashi Iwai
# 210269 2015-01-12 01:48:23+00:00   Daniel Vetter
# 210270 2015-01-12 01:48:22+00:00   Daniel Vetter
# 210271 2015-01-12 01:48:21+00:00   Daniel Vetter
# 249397 2014-07-04 05:47:22+00:00    Takashi Iwai
# 276684 2014-02-25 11:27:32+00:00    Takashi Iwai
# 327801 2013-06-06 15:31:56+00:00   Daniel Vetter
# 606665 2008-07-03 01:42:23+00:00  Linus Torvalds
# 607396 2008-06-24 18:17:25+00:00  Linus Torvalds
# 607763 2008-06-20 02:12:56+00:00     Dave Airlie
# 611668 2008-05-07 02:27:53+00:00     Dave Airlie
# ...                          ...             ...
# 665031 2006-12-07 04:53:30+00:00         airlied
# 665032 2006-12-07 04:53:30+00:00         airlied
# 665033 2006-12-07 04:53:30+00:00         airlied
# 665034 2006-12-07 04:53:30+00:00         airlied
# 665035 2006-12-07 04:53:30+00:00         airlied
# 665036 2006-12-07 04:53:29+00:00         airlied
# 665045 2006-12-07 04:53:28+00:00         airlied
# 672959 2006-09-21 19:32:34+00:00     Dave Airlie
# 672965 2006-09-21 19:32:33+00:00     Dave Airlie
# 672973 2006-09-21 19:32:32+00:00     Dave Airlie
# 672975 2006-09-21 19:32:32+00:00     Dave Airlie
# 678217 2006-06-24 07:32:58+00:00     Dave Airlie
# 685948 2006-03-20 07:34:29+00:00     Dave Airlie
# 685960 2006-03-19 09:28:19+00:00     Dave Airlie
# 687157 2006-02-18 04:17:04+00:00     Dave Airlie
# 688731 2006-01-25 04:31:43+00:00     Dave Airlie
# 690308 2006-01-10 16:01:34+00:00  Linus Torvalds
# 692228 2006-01-02 09:14:23+00:00     Dave Airlie
# 692238 2006-01-02 02:54:04+00:00     Dave Airlie
# 694074 2005-11-11 12:30:27+00:00     Dave Airlie
# 694195 2005-11-10 11:16:34+00:00     Dave Airlie
# 698215 2005-09-30 08:37:36+00:00     Dave Airlie
# 698448 2005-09-25 05:07:24+00:00     Dave Airlie
# 698450 2005-09-25 04:28:13+00:00     Dave Airlie
# 703345 2005-07-10 07:31:26+00:00     Dave Airlie
# 703350 2005-07-10 05:38:56+00:00     Dave Airlie
# 703354 2005-07-10 02:46:19+00:00     Dave Airlie
# 703577 2005-07-07 11:51:26+00:00     Dave Airlie
# 703579 2005-07-07 11:03:38+00:00     Dave Airlie
# 704962 2005-06-23 12:46:46+00:00     Dave Airlie
#
#                       committer_email  \
# 15098                   tiwai@suse.de
# 61969         shuahkh@osg.samsung.com
# 111442                  tiwai@suse.de
# 115950                  tiwai@suse.de
# 116855                  tiwai@suse.de
# 116888                  tiwai@suse.de
# 117311                  tiwai@suse.de
# 120549                  tiwai@suse.de
# 133034                  tiwai@suse.de
# 140663                  tiwai@suse.de
# 148493                  tiwai@suse.de
# 161447                  tiwai@suse.de
# 161449                  tiwai@suse.de
# 171000                  tiwai@suse.de
# 177911                  tiwai@suse.de
# 183136                  tiwai@suse.de
# 186689                  tiwai@suse.de
# 187602                  tiwai@suse.de
# 188626                  tiwai@suse.de
# 201637                  tiwai@suse.de
# 210269         daniel.vetter@ffwll.ch
# 210270         daniel.vetter@ffwll.ch
# 210271         daniel.vetter@ffwll.ch
# 249397                  tiwai@suse.de
# 276684                  tiwai@suse.de
# 327801         daniel.vetter@ffwll.ch
# 606665  torvalds@linux-foundation.org
# 607396  torvalds@linux-foundation.org
# 607763             airlied@redhat.com
# 611668               airlied@linux.ie
# ...                               ...
# 665031               airlied@linux.ie
# 665032               airlied@linux.ie
# 665033               airlied@linux.ie
# 665034               airlied@linux.ie
# 665035               airlied@linux.ie
# 665036               airlied@linux.ie
# 665045               airlied@linux.ie
# 672959               airlied@linux.ie
# 672965               airlied@linux.ie
# 672973               airlied@linux.ie
# 672975               airlied@linux.ie
# 678217               airlied@linux.ie
# 685948               airlied@linux.ie
# 685960               airlied@linux.ie
# 687157               airlied@linux.ie
# 688731               airlied@linux.ie
# 690308           torvalds@g5.osdl.org
# 692228               airlied@linux.ie
# 692238               airlied@linux.ie
# 694074               airlied@linux.ie
# 694195               airlied@linux.ie
# 698215               airlied@linux.ie
# 698448               airlied@linux.ie
# 698450               airlied@linux.ie
# 703345               airlied@linux.ie
# 703350               airlied@linux.ie
# 703354               airlied@linux.ie
# 703577               airlied@linux.ie
# 703579               airlied@linux.ie
# 704962               airlied@linux.ie
#
#                                                   summary  \
# 15098                  ALSA: hda: constify pci_device_id.
# 61969   kselftests: Exercise hw-independent mock tests...
# 111442  ALSA: hda - Update BCLK also at hotplug for i9...
# 115950  ALSA: hda - Bind with i915 only when Intel gra...
# 116855  ALSA: hda - Fix yet another i915 pointer lefto...
# 116888  ALSA: hda - Clear the leftover component assig...
# 117311  ALSA: hda - Add the pin / port mapping on Inte...
# 120549  ALSA: hda - Add a sanity check of pin / port m...
# 133034   ALSA: hda - Degrade i915 binding failure message
# 140663  ALSA: hda - Move audio component accesses to h...
# 148493          ALSA: hda - Add / fix kernel doc comments
# 161447  ALSA: hda - Fix missing inline for dummy snd_h...
# 161449  ALSA: hda - allow codecs to access the i915 pi...
# 171000              ALSA: hda - Fix Skylake codec timeout
# 177911  ALSA: hda - Allow calling snd_hdac_i915_*() wi...
# 183136  ALSA: hda - Move hda_i915.c from sound/pci/hda...
# 186689      ALSA: hda - reset display codec when power on
# 187602  ALSA: hda - implement a refcount for i915 powe...
# 188626  ALSA: hda - only sync BCLK to the display cloc...
# 201637  ALSA: hda - Fold hda_priv.h into hda_controller.h
# 210269                   ALSA: hda: add component support
# 210270  ALSA: hda: pass intel_hda to all i915 interfac...
# 210271                 ALSA: hda: export struct hda_intel
# 249397  ALSA: hda - restore BCLK M/N value as per CDCL...
# 276684           ALSA: hda - Replace with standard printk
# 327801  ALSA: hda - Add power-welll support for haswel...
# 606665             DRM/i915: only use tiled blits on 965+
# 607396        enable bus mastering on i915 at resume time
# 607763  drm/i915: add support for Intel series 4 chips...
# 611668  drm/i915: save and restore dsparb and d_state ...
# ...                                                   ...
# 665031  drm: i915: Only return EBUSY after we've estab...
# 665032  drm: i915: Fix 'sequence has passed' condition...
# 665033  drm: i915: Add SAREA fileds for determining wh...
# 665034  drm: Make handling of dev_priv->vblank_pipe mo...
# 665035  drm: DRM_I915_VBLANK_SWAP ioctl: Take drm_vbla...
# 665036  drm: i915: Add ioctl for scheduling buffer swa...
# 665045  drm: add support for secondary vertical blank ...
# 672959  drm: add device/vendor id to drm_device_t for ...
# 672965                        drm: fixup i915 error codes
# 672973                            drm: fix i965 build bug
# 672975         drm: Add support for Intel i965G chipsets.
# 678217  Add i915 ioctls to configure pipes for vblank ...
# 685948                drm: read breadcrumb in IRQ handler
# 685960              drm: fixup i915 breadcrumb read/write
# 687157         drm: fixup i915 interrupt on X server exit
# 688731           drm: i915 patches from Tungsten Graphics
# 690308         [PATCH] don't include ioctl32.h in drivers
# 692228                          drm: update to i915 1.3.0
# 692238      drm: move ioctl flags to a bit field of flags
# 694074                           drm: drop mtrr from i915
# 694195       drm: rename driver hooks more understandably
# 698215          drm: fix all sparse warning on 32-bit x86
# 698448                       drm: fix some lindent damage
# 698450                    drm: lindent the drm directory.
# 703345  drm: add test for AGP devices and driver overr...
# 703350            drm: update support for drm pci buffers
# 703354                 drm: fix stupid missing semicolon.
# 703577           drm: add 32/64 support for MGA/R128/i915
# 703579                                  drm: misc cleanup
# 704962  Add missing license texts from Tungsten Graphics.
#
#                                                   message  \
# 15098   ALSA: hda: constify pci_device_id.\n\npci_devi...
# 61969   kselftests: Exercise hw-independent mock tests...
# 111442  ALSA: hda - Update BCLK also at hotplug for i9...
# 115950  ALSA: hda - Bind with i915 only when Intel gra...
# 116855  ALSA: hda - Fix yet another i915 pointer lefto...
# 116888  ALSA: hda - Clear the leftover component assig...
# 117311  ALSA: hda - Add the pin / port mapping on Inte...
# 120549  ALSA: hda - Add a sanity check of pin / port m...
# 133034  ALSA: hda - Degrade i915 binding failure messa...
# 140663  ALSA: hda - Move audio component accesses to h...
# 148493  ALSA: hda - Add / fix kernel doc comments\n\nG...
# 161447  ALSA: hda - Fix missing inline for dummy snd_h...
# 161449  ALSA: hda - allow codecs to access the i915 pi...
# 171000  ALSA: hda - Fix Skylake codec timeout\n\nWhen ...
# 177911  ALSA: hda - Allow calling snd_hdac_i915_*() wi...
# 183136  ALSA: hda - Move hda_i915.c from sound/pci/hda...
# 186689  ALSA: hda - reset display codec when power on\...
# 187602  ALSA: hda - implement a refcount for i915 powe...
# 188626  ALSA: hda - only sync BCLK to the display cloc...
# 201637  ALSA: hda - Fold hda_priv.h into hda_controlle...
# 210269  ALSA: hda: add component support\n\nRegister a...
# 210270  ALSA: hda: pass intel_hda to all i915 interfac...
# 210271  ALSA: hda: export struct hda_intel\n\nThis str...
# 249397  ALSA: hda - restore BCLK M/N value as per CDCL...
# 276684  ALSA: hda - Replace with standard printk\n\nUs...
# 327801  ALSA: hda - Add power-welll support for haswel...
# 606665  DRM/i915: only use tiled blits on 965+\n\nWhen...
# 607396  enable bus mastering on i915 at resume time\n\...
# 607763  drm/i915: add support for Intel series 4 chips...
# 611668  drm/i915: save and restore dsparb and d_state ...
# ...                                                   ...
# 665031  drm: i915: Only return EBUSY after we've estab...
# 665032  drm: i915: Fix 'sequence has passed' condition...
# 665033  drm: i915: Add SAREA fileds for determining wh...
# 665034  drm: Make handling of dev_priv->vblank_pipe mo...
# 665035  drm: DRM_I915_VBLANK_SWAP ioctl: Take drm_vbla...
# 665036  drm: i915: Add ioctl for scheduling buffer swa...
# 665045  drm: add support for secondary vertical blank ...
# 672959  drm: add device/vendor id to drm_device_t for ...
# 672965  drm: fixup i915 error codes\n\nFrederik Deweer...
# 672973  drm: fix i965 build bug\n\nSigned-off-by: Andr...
# 672975  drm: Add support for Intel i965G chipsets.\n\n...
# 678217  Add i915 ioctls to configure pipes for vblank ...
# 685948  drm: read breadcrumb in IRQ handler\n\nFrom: K...
# 685960  drm: fixup i915 breadcrumb read/write\n\nSome ...
# 687157  drm: fixup i915 interrupt on X server exit\n\n...
# 688731  drm: i915 patches from Tungsten Graphics\n\nFi...
# 690308  [PATCH] don't include ioctl32.h in drivers\n\n...
# 692228  drm: update to i915 1.3.0\n\nAdd support for v...
# 692238  drm: move ioctl flags to a bit field of flags\...
# 694074  drm: drop mtrr from i915\n\nAlan Hourihane wan...
# 694195  drm: rename driver hooks more understandably\n...
# 698215  drm: fix all sparse warning on 32-bit x86\n\nF...
# 698448  drm: fix some lindent damage\n\nSigned-off-by:...
# 698450  drm: lindent the drm directory.\n\nI've been t...
# 703345  drm: add test for AGP devices and driver overr...
# 703350  drm: update support for drm pci buffers\n\nThe...
# 703354  drm: fix stupid missing semicolon.\n\nI fixed ...
# 703577  drm: add 32/64 support for MGA/R128/i915\n\nTh...
# 703579  drm: misc cleanup\n\nThis patch contains the f...
# 704962  Add missing license texts from Tungsten Graphi...
#
#                                                     files  isDRM  isi915  \
# 15098                               sound/hda/hdac_i915.c  False   False
# 61969         tools/testing/selftests/drivers/gpu/i915.sh  False   False
# 111442  include/sound/hda_i915.h,sound/hda/hdac_i915.c...  False   False
# 115950                              sound/hda/hdac_i915.c  False   False
# 116855                              sound/hda/hdac_i915.c  False   False
# 116888                              sound/hda/hdac_i915.c  False   False
# 117311  include/sound/hda_i915.h,sound/hda/hdac_i915.c...  False   False
# 120549                              sound/hda/hdac_i915.c  False   False
# 133034    sound/hda/hdac_i915.c,sound/pci/hda/hda_intel.c  False   False
# 140663  include/sound/hda_i915.h,sound/hda/hdac_i915.c...  False   False
# 148493  sound/hda/hdac_bus.c,sound/hda/hdac_device.c,s...  False   False
# 161447                           include/sound/hda_i915.h  False   False
# 161449     include/sound/hda_i915.h,sound/hda/hdac_i915.c  False   False
# 171000    sound/hda/hdac_i915.c,sound/pci/hda/hda_intel.c  False   False
# 177911                              sound/hda/hdac_i915.c  False   False
# 183136  include/sound/hda_i915.h,include/sound/hda_reg...  False   False
# 186689  sound/pci/hda/hda_i915.c,sound/pci/hda/hda_int...  False   False
# 187602  sound/pci/hda/hda_i915.c,sound/pci/hda/hda_int...  False   False
# 188626                           sound/pci/hda/hda_i915.c  False   False
# 201637  sound/pci/hda/hda_controller.c,sound/pci/hda/h...  False   False
# 210269  sound/pci/hda/hda_i915.c,sound/pci/hda/hda_int...  False   False
# 210270  sound/pci/hda/hda_i915.c,sound/pci/hda/hda_int...  False   False
# 210271  sound/pci/hda/hda_i915.c,sound/pci/hda/hda_int...  False   False
# 249397  sound/pci/hda/hda_i915.c,sound/pci/hda/hda_i91...  False   False
# 276684  sound/pci/hda/hda_auto_parser.c,sound/pci/hda/...  False   False
# 327801  sound/pci/hda/Kconfig,sound/pci/hda/Makefile,s...  False   False
# 606665                        drivers/char/drm/i915_irq.c  False   False
# 607396                        drivers/char/drm/i915_drv.c  False   False
# 607763  drivers/char/drm/drm_pciids.h,drivers/char/drm...  False   False
# 611668  drivers/char/drm/i915_drv.c,drivers/char/drm/i...  False   False
# ...                                                   ...    ...     ...
# 665031                        drivers/char/drm/i915_irq.c  False   False
# 665032                        drivers/char/drm/i915_irq.c  False   False
# 665033                        drivers/char/drm/i915_drm.h  False   False
# 665034                        drivers/char/drm/i915_irq.c  False   False
# 665035  drivers/char/drm/i915_drm.h,drivers/char/drm/i...  False   False
# 665036  drivers/char/drm/i915_dma.c,drivers/char/drm/i...  False   False
# 665045  drivers/char/drm/i915_drv.c,drivers/char/drm/i...  False   False
# 672959  drivers/char/drm/drmP.h,drivers/char/drm/drm_s...  False   False
# 672965                        drivers/char/drm/i915_dma.c  False   False
# 672973                        drivers/char/drm/i915_dma.c  False   False
# 672975  drivers/char/drm/drm_pciids.h,drivers/char/drm...  False   False
# 678217  drivers/char/drm/i915_dma.c,drivers/char/drm/i...  False   False
# 685948                        drivers/char/drm/i915_irq.c  False   False
# 685960                        drivers/char/drm/i915_dma.c  False   False
# 687157                        drivers/char/drm/i915_irq.c  False   False
# 688731  drivers/char/drm/i915_dma.c,drivers/char/drm/i...  False   False
# 690308  arch/s390/kernel/s390_ksyms.c,arch/x86_64/kern...  False   False
# 692228  drivers/char/drm/i915_dma.c,drivers/char/drm/i...  False   False
# 692238  drivers/char/drm/drmP.h,drivers/char/drm/drm_d...  False   False
# 694074                        drivers/char/drm/i915_drv.c  False   False
# 694195  drivers/char/drm/drmP.h,drivers/char/drm/drm_d...  False   False
# 698215  drivers/char/drm/drm_bufs.c,drivers/char/drm/d...  False   False
# 698448  drivers/char/drm/i810_dma.c,drivers/char/drm/i...  False   False
# 698450  drivers/char/drm/ati_pcigart.c,drivers/char/dr...  False   False
# 703345  drivers/char/drm/drmP.h,drivers/char/drm/drm_s...  False   False
# 703350  drivers/char/drm/drmP.h,drivers/char/drm/drm_b...  False   False
# 703354                        drivers/char/drm/i915_drv.h  False   False
# 703577  drivers/char/drm/Makefile,drivers/char/drm/i91...  False   False
# 703579  drivers/char/drm/ati_pcigart.c,drivers/char/dr...  False   False
# 704962  drivers/char/drm/i915_dma.c,drivers/char/drm/i...  False   False
#
#         isi9152
# 15098      True
# 61969      True
# 111442     True
# 115950     True
# 116855     True
# 116888     True
# 117311     True
# 120549     True
# 133034     True
# 140663     True
# 148493     True
# 161447     True
# 161449     True
# 171000     True
# 177911     True
# 183136     True
# 186689     True
# 187602     True
# 188626     True
# 201637     True
# 210269     True
# 210270     True
# 210271     True
# 249397     True
# 276684     True
# 327801     True
# 606665     True
# 607396     True
# 607763     True
# 611668     True
# ...         ...
# 665031     True
# 665032     True
# 665033     True
# 665034     True
# 665035     True
# 665036     True
# 665045     True
# 672959     True
# 672965     True
# 672973     True
# 672975     True
# 678217     True
# 685948     True
# 685960     True
# 687157     True
# 688731     True
# 690308     True
# 692228     True
# 692238     True
# 694074     True
# 694195     True
# 698215     True
# 698448     True
# 698450     True
# 703345     True
# 703350     True
# 703354     True
# 703577     True
# 703579     True
# 704962     True
#
# [102 rows x 13 columns]

# %%
result = {}
for year in range(2013,2018):
    for month in range(1,13):
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        if year == 2017 and month > 6:
            break
        print year, month
        print subset.committer_name.value_counts(normalize=True)[:1]
        result[(year,month)] = subset.committer_name.value_counts(normalize=True)[:1].sum()
# Out:
# 2013 1
# Daniel Vetter    0.967213
# Name: committer_name, dtype: float64
# 2013 2
# Daniel Vetter    0.946429
# Name: committer_name, dtype: float64
# 2013 3
# Daniel Vetter    0.976744
# Name: committer_name, dtype: float64
# 2013 4
# Daniel Vetter    0.994475
# Name: committer_name, dtype: float64
# 2013 5
# Daniel Vetter    0.986014
# Name: committer_name, dtype: float64
# 2013 6
# Daniel Vetter    0.972973
# Name: committer_name, dtype: float64
# 2013 7
# Daniel Vetter    0.960396
# Name: committer_name, dtype: float64
# 2013 8
# Daniel Vetter    0.938889
# Name: committer_name, dtype: float64
# 2013 9
# Daniel Vetter    0.97546
# Name: committer_name, dtype: float64
# 2013 10
# Daniel Vetter    0.95057
# Name: committer_name, dtype: float64
# 2013 11
# Daniel Vetter    0.981221
# Name: committer_name, dtype: float64
# 2013 12
# Daniel Vetter    0.962264
# Name: committer_name, dtype: float64
# 2014 1
# Daniel Vetter    0.940476
# Name: committer_name, dtype: float64
# 2014 2
# Daniel Vetter    0.989011
# Name: committer_name, dtype: float64
# 2014 3
# Daniel Vetter    0.920354
# Name: committer_name, dtype: float64
# 2014 4
# Daniel Vetter    0.878205
# Name: committer_name, dtype: float64
# 2014 5
# Daniel Vetter    0.954373
# Name: committer_name, dtype: float64
# 2014 6
# Daniel Vetter    0.834437
# Name: committer_name, dtype: float64
# 2014 7
# Daniel Vetter    0.863158
# Name: committer_name, dtype: float64
# 2014 8
# Daniel Vetter    0.891892
# Name: committer_name, dtype: float64
# 2014 9
# Daniel Vetter    0.933333
# Name: committer_name, dtype: float64
# 2014 10
# Daniel Vetter    0.914894
# Name: committer_name, dtype: float64
# 2014 11
# Daniel Vetter    0.957854
# Name: committer_name, dtype: float64
# 2014 12
# Daniel Vetter    0.857143
# Name: committer_name, dtype: float64
# 2015 1
# Daniel Vetter    0.931507
# Name: committer_name, dtype: float64
# 2015 2
# Daniel Vetter    0.896341
# Name: committer_name, dtype: float64
# 2015 3
# Daniel Vetter    0.924171
# Name: committer_name, dtype: float64
# 2015 4
# Daniel Vetter    0.883495
# Name: committer_name, dtype: float64
# 2015 5
# Daniel Vetter    0.95935
# Name: committer_name, dtype: float64
# 2015 6
# Daniel Vetter    0.709302
# Name: committer_name, dtype: float64
# 2015 7
# Daniel Vetter    0.988506
# Name: committer_name, dtype: float64
# 2015 8
# Daniel Vetter    0.856164
# Name: committer_name, dtype: float64
# 2015 9
# Daniel Vetter    0.87251
# Name: committer_name, dtype: float64
# 2015 10
# Daniel Vetter    0.739726
# Name: committer_name, dtype: float64
# 2015 11
# Ville Syrjälä    0.299517
# Name: committer_name, dtype: float64
# 2015 12
# Jani Nikula    0.304094
# Name: committer_name, dtype: float64
# 2016 1
# Daniel Vetter    0.21256
# Name: committer_name, dtype: float64
# 2016 2
# Jani Nikula    0.279221
# Name: committer_name, dtype: float64
# 2016 3
# Jani Nikula    0.166667
# Name: committer_name, dtype: float64
# 2016 4
# Chris Wilson    0.293729
# Name: committer_name, dtype: float64
# 2016 5
# Ville Syrjälä    0.245192
# Name: committer_name, dtype: float64
# 2016 6
# Chris Wilson    0.398496
# Name: committer_name, dtype: float64
# 2016 7
# Chris Wilson    0.530516
# Name: committer_name, dtype: float64
# 2016 8
# Chris Wilson    0.616848
# Name: committer_name, dtype: float64
# 2016 9
# Rodrigo Vivi    0.261745
# Name: committer_name, dtype: float64
# 2016 10
# Chris Wilson    0.25656
# Name: committer_name, dtype: float64
# 2016 11
# Chris Wilson    0.264407
# Name: committer_name, dtype: float64
# 2016 12
# Ville Syrjälä    0.20614
# Name: committer_name, dtype: float64
# 2017 1
# Chris Wilson    0.492188
# Name: committer_name, dtype: float64
# 2017 2
# Chris Wilson    0.514512
# Name: committer_name, dtype: float64
# 2017 3
# Chris Wilson    0.329975
# Name: committer_name, dtype: float64
# 2017 4
# Chris Wilson    0.411765
# Name: committer_name, dtype: float64
# 2017 5
# Chris Wilson    0.312821
# Name: committer_name, dtype: float64
# 2017 6
# Chris Wilson    0.252137
# Name: committer_name, dtype: float64

# %%
plt.figure(facecolor="white")
s = pd.Series(result)
s.plot('bar', figsize=(16,9), color='blue')

# %%
print pd.Series([v for k,v in result.items() if k < (2015,9)]).describe()
print pd.Series([v for k,v in result.items() if k > (2015,12)]).describe()
# Out:
# count    32.000000
# mean      0.928019
# std       0.059602
# min       0.709302
# 25%       0.895229
# 50%       0.943452
# 75%       0.968653
# max       0.994475
# dtype: float64
# count    18.000000
# mean      0.335860
# std       0.128614
# min       0.166667
# 25%       0.253243
# 50%       0.286475
# 75%       0.408448
# max       0.616848
# dtype: float64

# %%
result_a = {}
for year in range(2013,2018):
    for month in range(1,13):
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        if year == 2017 and month > 6:
            break
        result_a[(year,month)] = subset.committer_name.value_counts(normalize=False)[:1].sum()
plt.figure(facecolor="white")
s = pd.Series(result_a)
s.plot('bar', figsize=(16,9), color='blue')

# %%
print pd.Series([v for k,v in result_a.items() if k < (2015,9)]).describe()
print pd.Series([v for k,v in result_a.items() if k > (2015,12)]).describe()
# Out:
# count     32.000000
# mean     163.906250
# std       48.939963
# min       53.000000
# 25%      133.500000
# 50%      161.500000
# 75%      194.250000
# max      251.000000
# dtype: float64
# count     18.000000
# mean      88.111111
# std       54.310533
# min       33.000000
# 25%       48.000000
# 50%       69.500000
# 75%      111.250000
# max      227.000000
# dtype: float64

# %%
result_a = {}
for year in range(2013,2018):
    for month in range(1,13):
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        if year == 2017 and month > 6:
            break
        result_a[(year,month)] = subset.committer_name.value_counts(normalize=False)[:2].sum()

# %%
plt.figure(facecolor="white")
s = pd.Series(result_a)
s.plot('bar', figsize=(16,9), color='blue')

# %%
print pd.Series([v for k,v in result.items() if k < (2015,9)]).describe()
print pd.Series([v for k,v in result.items() if k > (2015,12)]).describe()
# Out:
# count    32.000000
# mean      0.928019
# std       0.059602
# min       0.709302
# 25%       0.895229
# 50%       0.943452
# 75%       0.968653
# max       0.994475
# dtype: float64
# count    18.000000
# mean      0.335860
# std       0.128614
# min       0.166667
# 25%       0.253243
# 50%       0.286475
# 75%       0.408448
# max       0.616848
# dtype: float64

# %%
print pd.Series([v for k,v in result_a.items() if k < (2015,9)]).describe()
print pd.Series([v for k,v in result_a.items() if k > (2015,12)]).describe()
# Out:
# count     32.000000
# mean     174.750000
# std       52.589708
# min       54.000000
# 25%      145.250000
# 50%      172.000000
# 75%      207.500000
# max      263.000000
# dtype: float64
# count     18.000000
# mean     131.666667
# std       57.382104
# min       64.000000
# 25%       85.750000
# 50%      118.500000
# 75%      154.750000
# max      267.000000
# dtype: float64

# %%
# exclude 2015.9 ~ 2015.12

# %%
selected[selected.committed_datetime.map(lambda t: t.year * 100 + t.month).map(lambda d: d >= 201300 and d < 201700)].committed_datetime.map(lambda t: t.year*100+t.month).value_counts().sort_index().plot('bar',figsize=(32,18), color='blue')

# %%
s = selected[selected.committed_datetime.map(lambda t: t.year * 100 + t.month).map(lambda d: d >= 201211 and d < 201707)].committed_datetime.map(lambda t: t.year*100+t.month).value_counts().sort_index()

# %%
plt.figure(facecolor="white")
s = s.rolling(window=3, center=False).mean()
s = s[(s.index > 201300) & (s.index < 201700)]
s.plot('bar',figsize=(32,18), color='blue')
# Out:
# D:\Dev\Anaconda2\lib\site-packages\ipykernel\__main__.py:2: FutureWarning: pd.rolling_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=3,center=False).mean()
#   from ipykernel import kernelapp as app

# %%
## overwork

# %%
result = {}
for year in range(2013,2018):
    for month in range(1,13):
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        if year == 2017 and month > 6:
            break
        committers = subset.committer_name.value_counts(normalize=True)
        acc = 0.0
        for committer in committers.index:
            df = subset[subset.committer_name == committer]
            s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
            if len(s) > 8:
                acc += s[8:].sum() * committers[committer]
        result[(year,month)] = acc

# %%
plt.figure(facecolor='white')
pd.Series(result).plot('bar', color='blue', figsize=(16,9))

# %%
print pd.Series([v for k,v in result.items() if k < (2015,9)]).describe()
print pd.Series([v for k,v in result.items() if k > (2015,12)]).describe()
# Out:
# count    32.000000
# mean      0.084679
# std       0.060403
# min       0.000000
# 25%       0.041084
# 50%       0.065973
# 75%       0.125560
# max       0.232558
# dtype: float64
# count    18.000000
# mean      0.034338
# std       0.033525
# min       0.000000
# 25%       0.009990
# 50%       0.022144
# 75%       0.053727
# max       0.103275
# dtype: float64

# %%
## touched files

# %%
def count_distinct_files(files_list):
    file_set = set()
    for files in files_list:
        if len(files) == 0:
            continue
        files = files.split(",")
        if len(files) > 230:
            continue
        for f in files:
            file_set.add(f)
    return len(file_set)

# %%
result = {}
for year in range(2013,2018):
    for month in range(1,13):
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        if year == 2017 and month > 6:
            break
        top2 = subset.committer_name.value_counts()[:2]
        arr = []
        for committer in top2.index:
            arr.append(count_distinct_files(subset[subset.committer_name == committer]['files']))
        result[(year,month)] = arr

# %%
plt.figure(facecolor='white')
pd.DataFrame(result).T[0].plot('bar', color='blue', figsize=(16,9))

# %%
print pd.Series([v[0] for k,v in result.items() if k < (2015,9)]).describe()
print pd.Series([v[0] for k,v in result.items() if k > (2015,12)]).describe()
# Out:
# count    32.000000
# mean     46.968750
# std      13.362162
# min      29.000000
# 25%      38.000000
# 50%      46.500000
# 75%      53.000000
# max      86.000000
# dtype: float64
# count     18.000000
# mean      52.000000
# std       25.005882
# min       24.000000
# 25%       33.500000
# 50%       51.500000
# 75%       59.250000
# max      120.000000
# dtype: float64

# %%
subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (2016 * 1000 + 12)]

# %%
top2 = subset.committer_name.value_counts()[:2]

# %%
committer = top2.index[0]

# %%
subset[subset.committer_name == committer]['files'].map(lambda f: len(f.split(',')))
# Out:
# 59794     1
# 59811     3
# 59812     1
# 59813     1
# 59814     1
# 59815     1
# 59816     1
# 59817     1
# 59819     1
# 59821     2
# 59823     1
# 59853     1
# 59856     1
# 60110     2
# 60523     6
# 60524    54
# 60525    44
# 60526    36
# 60527     1
# 60529     2
# 60532    15
# 60533     1
# 60534    13
# 60536     1
# 60539     1
# 60548    24
# 60799     1
# 62135     1
# 62136     2
# 62167     3
# 62707     1
# 62750     1
# 62751     1
# 62752     1
# 62753     1
# 62754     3
# 62755     2
# 62756     1
# 62757     1
# 62758     2
# 62759     1
# 62760     1
# 62761     1
# 62762     1
# 62763     1
# 62764     3
# 62765     1
# Name: files, dtype: int64

# %%
## authors

# %%
result = {}
for year in range(2013,2018):
    for month in range(1,13):
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        if year == 2017 and month > 6:
            break
        top2 = subset.committer_name.value_counts()[:2]
        arr = []
        for committer in top2.index:
            arr.append(len(set(subset[subset.committer_name == committer]['author_name'])))
        result[(year,month)] = arr

# %%
plt.figure(facecolor='white')
pd.DataFrame(result).T[0].plot('bar', color='blue', figsize=(16,9))

# %%
print pd.Series([v[0] for k,v in result.items() if k < (2015,9)]).describe()
print pd.Series([v[0] for k,v in result.items() if k > (2015,12)]).describe()
# Out:
# count    32.000000
# mean     22.187500
# std       6.741482
# min      11.000000
# 25%      16.750000
# 50%      21.500000
# 75%      27.250000
# max      35.000000
# dtype: float64
# count    18.000000
# mean      6.944444
# std       3.764731
# min       2.000000
# 25%       4.000000
# 50%       7.000000
# 75%       9.000000
# max      16.000000
# dtype: float64

# %%
# tag

# %%
result = {}
for year in range(2013,2018):
    for month in range(1,13):
        if year == 2017 and month > 6:
            break
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        desc = subset.message.map(lambda m:  "Acked-by" in m or "Reviewed-by" in m or "Tested-by" in m ).value_counts(normalize=True)[True]
        result[(year,month)] = desc

# %%
plt.figure(facecolor='white')
pd.Series(result).plot('bar', figsize=(16,9), color='blue')

# %%
print pd.Series([v for k,v in result.items() if k < (2015,9)]).describe()
print pd.Series([v for k,v in result.items() if k > (2015,12)]).describe()
# Out:
# count    32.000000
# mean      0.740988
# std       0.081746
# min       0.557377
# 25%       0.709961
# 50%       0.740885
# 75%       0.780179
# max       0.895349
# dtype: float64
# count    18.000000
# mean      0.902121
# std       0.037429
# min       0.833819
# 25%       0.875792
# 50%       0.903514
# 75%       0.928400
# max       0.956522
# dtype: float64

# %%
# delay

# %%
result = {}
for year in range(2013,2018):
    for month in range(1,13):
        if year == 2017 and month > 6:
            break
        subset = selected[selected.committed_datetime.map(lambda t: t.year * 1000 + t.month) == (year * 1000 + month)]
        desc = (subset.committed_datetime - subset.authored_datetime).median()
        result[(year,month)] = desc

# %%
plt.figure(facecolor="white")
pd.Series(result).map(lambda t: t.total_seconds()*1.0 / 86400).plot('bar', color='blue', figsize=(16,9))

# %%
before = selected[selected.committed_datetime.map(lambda t: t.year * 100 + t.month).map(lambda d: d >= 201300 and d < 201509)]
after = selected[selected.committed_datetime.map(lambda t: t.year * 100 + t.month).map(lambda d: d >= 201600 and d < 201707)]

# %%
(before.committed_datetime - before.authored_datetime).describe()
# Out:
# count                       5673
# mean     11 days 19:55:10.159351
# std      31 days 22:48:57.066664
# min            -1 days +03:05:48
# 25%              1 days 02:28:44
# 50%              5 days 11:02:13
# 75%             11 days 19:40:16
# max            587 days 21:05:48
# Name: committed_datetime, dtype: object

# %%
(after.committed_datetime - after.authored_datetime).describe()
# Out:
# count                       4529
# mean      6 days 04:30:39.289247
# std      18 days 18:42:20.741705
# min            -5 days +17:45:30
# 25%              0 days 03:29:23
# 50%              0 days 23:05:55
# 75%              5 days 16:30:05
# max            393 days 10:45:27
# Name: committed_datetime, dtype: object
