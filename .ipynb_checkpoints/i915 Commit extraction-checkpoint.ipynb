# %%
from git import Repo
import pandas as pd

# %%
def changed_files(c):
    if len(c.parents) != 1:
        return ""
    return ','.join([d.a_path for d in c.diff(c.parents[0])])

# %%
repo_dir = "D:\drm-intel"
first_run = True

if first_run:
    repo = Repo(repo_dir)
    commits = list(repo.iter_commits("drm-intel-next-queued"))
    def isValid(c):
        try:
            c.authored_datetime, c.committed_datetime
            return True
        except:
            return False
    commit_list = map(lambda c: (c.hexsha, c.authored_datetime, c.author.name, c.author.email, c.committed_datetime, c.committer.name, c.committer.email, c.summary, c.message, changed_files(c)), filter(lambda c: isValid(c), commits))
    commit_df = pd.DataFrame(commit_list, columns='hexsha,authored_datetime,author_name,author_email,committed_datetime,committer_name,committer_email,summary,message,files'.split(','))
    commit_df['authored_datetime'] = pd.to_datetime(commit_df['authored_datetime'], utc=True)
    commit_df['committed_datetime'] = pd.to_datetime(commit_df['committed_datetime'], utc=True)
    commit_df.to_pickle("i915.pkl")
else:
    commit_df = pd.read_pickle("i915.pkl")
# Out:
# ---------------------------------------------------------------------------
# GitCommandError                           Traceback (most recent call last)
# <ipython-input-5-3639165d839c> in <module>()
#       4 if first_run:
#       5     repo = Repo(repo_dir)
# ----> 6     commits = list(repo.iter_commits("master"))
#       7     def isValid(c):
#       8         try:
#
# D:\Dev\Anaconda2\lib\site-packages\git\objects\commit.pyc in _iter_from_process_or_stream(cls, repo, proc_or_stream)
#     277         # due to many developers trying to fix the open file handles issue
#     278         if hasattr(proc_or_stream, 'wait'):
# --> 279             finalize_process(proc_or_stream)
#     280
#     281     @classmethod
#
# D:\Dev\Anaconda2\lib\site-packages\git\util.pyc in finalize_process(proc, **kwargs)
#     339     """Wait for the process (clone, fetch, pull or push) and handle its errors accordingly"""
#     340     ## TODO: No close proc-streams??
# --> 341     proc.wait(**kwargs)
#     342
#     343
#
# D:\Dev\Anaconda2\lib\site-packages\git\cmd.pyc in wait(self, stderr)
#     416                 errstr = read_all_from_possibly_closed_stream(self.proc.stderr)
#     417                 log.debug('AutoInterrupt wait stderr: %r' % (errstr,))
# --> 418                 raise GitCommandError(self.args, status, errstr)
#     419             # END status handling
#     420             return status
#
# GitCommandError: Cmd('git') failed due to: exit code(128)
#   cmdline: git rev-list master --
#   stderr: 'fatal: bad revision 'master'
# '

# %%
print "hello"
# Out:
# hello

# %%
pd.read_pickle("i915.pkl")
# Out:
#                                           hexsha         authored_datetime  \
# 0       39dae59d66acd86d1de24294bd2f343fd5e7a625 2017-11-05 21:05:14+00:00
# 1       9b3499d752fc292f37503e5c3a5e5df4f7e76d42 2017-11-05 20:14:50+00:00
# 2       b21172cf6dc6e2af21346e774ea2e7c784de30bd 2017-11-05 20:12:51+00:00
# 3       9d9cc4aa004edc996ce560e57b1154f658681c05 2017-11-05 19:44:39+00:00
# 4       c84e6d01eed16afa41a1c4ad9a6bd6a8bfe67af0 2017-11-05 19:43:20+00:00
# 10                Linus Torvalds  torvalds@linux-foundation.org
# 11                Linus Torvalds  torvalds@linux-foundation.org
# 12                Josh Poimboeuf            jpoimboe@redhat.com
# 13               Andy Lutomirski                luto@kernel.org
# 14                  Frank Rowand          frank.rowand@sony.com
# 15                 Willy Tarreau                       w@1wt.eu
# 16                   Ingo Molnar               mingo@kernel.org
# 17                Josh Poimboeuf            jpoimboe@redhat.com
# 18                   Ingo Molnar               mingo@kernel.org
# 19                Linus Torvalds  torvalds@linux-foundation.org
# 20                Linus Torvalds  torvalds@linux-foundation.org
# 21                  Stefan Brüns   stefan.bruens@rwth-aachen.de
# 22             Martin Kepplinger              martink@posteo.de
# 23                Linus Torvalds  torvalds@linux-foundation.org
# 24                Linus Torvalds  torvalds@linux-foundation.org
# 25                 Chris Metcalf          cmetcalf@mellanox.com
# 26                Linus Torvalds  torvalds@linux-foundation.org
# 27                Linus Torvalds  torvalds@linux-foundation.org
# 28                Linus Torvalds  torvalds@linux-foundation.org
# 29                Linus Torvalds  torvalds@linux-foundation.org
# ...                          ...                            ...
# 708076            Paul Mackerras               paulus@samba.org
# 708077            Paul Mackerras               paulus@samba.org
# 708078            Paul Mackerras               paulus@samba.org
# 708079          Eugene Surovegin                ebs@ebshome.net
# 708080            Paul Mackerras               paulus@samba.org
# 708081              James Morris             jmorris@redhat.com
# 708082           Jean Tourrilhes                  jt@hpl.hp.com
# 708083                Herbert Xu    herbert@gondor.apana.org.au
# 708084  Arnaldo Carvalho de Melo          acme@conectiva.com.br
# 708085           David S. Miller            davem@davemloft.net
# 708086              Martin Hicks                   mort@sgi.com
# 708087             akpm@osdl.org                  akpm@osdl.org
# 708088             akpm@osdl.org                  akpm@osdl.org
# 708089          Andrea Arcangeli                 andrea@suse.de
# 708090                Jeff Moyer              jmoyer@redhat.com
# 708091               Dave Airlie               airlied@linux.ie
# 708092              James Morris             jmorris@redhat.com
# 708093             akpm@osdl.org                  akpm@osdl.org
# 708094           David S. Miller            davem@davemloft.net
# 708095              Stas Sergeev                  stsp@aknet.ru
# 708096             akpm@osdl.org                  akpm@osdl.org
# 708097           James Bottomley   James.Bottomley@SteelEye.com
# 708098        Artem B. Bityuckiy         dedekind@infradead.org
# 708099             akpm@osdl.org                  akpm@osdl.org
# 708100             akpm@osdl.org                  akpm@osdl.org
# 708101             akpm@osdl.org                  akpm@osdl.org
# 708102             akpm@osdl.org                  akpm@osdl.org
# 708103                Neil Brown          neilb@cse.unsw.edu.au
# 708104         Christoph Lameter          clameter@engr.sgi.com
# 708105            Linus Torvalds       torvalds@ppc970.osdl.org
#
#               committed_datetime      committer_name  \
# 0      2017-11-05 21:05:14+00:00      Linus Torvalds
# 1      2017-11-05 20:14:50+00:00      Linus Torvalds
# 2      2017-11-05 20:12:51+00:00      Linus Torvalds
# 3      2017-11-05 19:44:39+00:00      Linus Torvalds
# 4      2017-11-05 19:43:20+00:00      Linus Torvalds
# 708099 2005-04-16 22:23:57+00:00      Linus Torvalds
# 708100 2005-04-16 22:23:57+00:00      Linus Torvalds
# 708101 2005-04-16 22:23:56+00:00      Linus Torvalds
# 708102 2005-04-16 22:23:55+00:00      Linus Torvalds
# 708103 2005-04-16 22:23:54+00:00      Linus Torvalds
# 708104 2005-04-16 22:23:53+00:00      Linus Torvalds
# 708105 2005-04-16 22:20:36+00:00      Linus Torvalds
#
#                       committer_email  \
# 0       torvalds@linux-foundation.org
# 1       torvalds@linux-foundation.org
# 2       torvalds@linux-foundation.org
# 3       torvalds@linux-foundation.org
# 4       torvalds@linux-foundation.org
# 5       torvalds@linux-foundation.org
# 6       torvalds@linux-foundation.org
# 7                    mingo@kernel.org
# 8       torvalds@linux-foundation.org
# 9       torvalds@linux-foundation.org
# 10      torvalds@linux-foundation.org
# 11      torvalds@linux-foundation.org
# 12                   mingo@kernel.org
# 13                   mingo@kernel.org
# 14         gregkh@linuxfoundation.org
# 15         gregkh@linuxfoundation.org
# 16                   mingo@kernel.org
# 17                   mingo@kernel.org
# 18                   mingo@kernel.org
# 19      torvalds@linux-foundation.org
# 20      torvalds@linux-foundation.org
# 21          dmitry.torokhov@gmail.com
# 22          dmitry.torokhov@gmail.com
# 23      torvalds@linux-foundation.org
# 24      torvalds@linux-foundation.org
# 25              cmetcalf@mellanox.com
# 26      torvalds@linux-foundation.org
# 27      torvalds@linux-foundation.org
# 28      torvalds@linux-foundation.org
# 29      torvalds@linux-foundation.org
# ...                               ...
# 708076       torvalds@ppc970.osdl.org
# 708077       torvalds@ppc970.osdl.org
# 708078       torvalds@ppc970.osdl.org
# 708079       torvalds@ppc970.osdl.org
# 708080       torvalds@ppc970.osdl.org
# 708081       torvalds@ppc970.osdl.org
# 708082       torvalds@ppc970.osdl.org
# 708083       torvalds@ppc970.osdl.org
# 708084       torvalds@ppc970.osdl.org
# 708085       torvalds@ppc970.osdl.org
# 708086       torvalds@ppc970.osdl.org
# 708087       torvalds@ppc970.osdl.org
# 708088       torvalds@ppc970.osdl.org
# 708089       torvalds@ppc970.osdl.org
# 708090       torvalds@ppc970.osdl.org
# 708091       torvalds@ppc970.osdl.org
# 708092       torvalds@ppc970.osdl.org
# 708093       torvalds@ppc970.osdl.org
# 708094       torvalds@ppc970.osdl.org
# 708095       torvalds@ppc970.osdl.org
# 708096       torvalds@ppc970.osdl.org
# 708097       torvalds@ppc970.osdl.org
# 708098       torvalds@ppc970.osdl.org
# 708099       torvalds@ppc970.osdl.org
# 708100       torvalds@ppc970.osdl.org
# 708101       torvalds@ppc970.osdl.org
# 708102       torvalds@ppc970.osdl.org
# 708103       torvalds@ppc970.osdl.org
# 708104       torvalds@ppc970.osdl.org
# 708105       torvalds@ppc970.osdl.org
#
#                                                   summary  \
# 0                                          Linux 4.14-rc8
# 1       Merge branch 'x86-urgent-for-linus' of git://g...
# 2       Merge branch 'ras-urgent-for-linus' of git://g...
# 3       Merge branch 'perf-urgent-for-linus' of git://...
# 4       Merge branch 'irq-urgent-for-linus' of git://g...
# 5       Merge branch 'core-urgent-for-linus' of git://...
# 6       Merge tag 'enforcement-4.14-rc8' of git://git....
# 7         x86/module: Detect and skip invalid relocations
# 8       Merge branch 'fixes' of git://git.armlinux.org...
# 9       Merge tag 'for-linus' of git://git.kernel.org/...
# 10      Merge tag 'armsoc-fixes' of git://git.kernel.o...
# 11      Merge tag 'mips_fixes_4.14' of git://git.kerne...
# 12      objtool: Prevent GCC from merging annotate_unr...
# 13      Revert "x86/mm: Stop calling leave_mm() in idl...
# 14      Documentation: Add Frank Rowand to list of enf...
# 15      doc: add Willy Tarreau to the list of enforcem...
# 16          tools/headers: Synchronize kernel ABI headers
# 17      objtool: Resync objtool's instruction decoder ...
# 18      Merge branch 'linus' into core/urgent, to pick...
# 19      Merge branch 'for-linus' of git://git.kernel.o...
# 20      Merge tag 'clk-fixes-for-linus' of git://git.k...
# 21      Input: sparse-keymap - send sync event for KE_...
# 22              Input: ar1021_i2c - set INPUT_PROP_DIRECT
# 23      Merge git://git.kernel.org/pub/scm/linux/kerne...
# 24      Merge tag 'scsi-fixes' of git://git.kernel.org...
# 25      arch/tile: Implement ->set_state_oneshot_stopp...
# 26      Merge tag 'powerpc-4.14-6' of git://git.kernel...
# 27      Merge tag 'mmc-v4.14-rc4-3' of git://git.kerne...
# 28      Merge tag 'drm-fixes-for-v4.14-rc8' of git://p...
# 29      Merge git://git.kernel.org/pub/scm/linux/kerne...
# ...                                                   ...
# 708076  [PATCH] ppc32: fix single-stepping of emulated...
# 708077  [PATCH] ppc32: oops on kernel altivec assist e...
# 708078       [PATCH] ppc32: improve timebase sync for SMP
# 708079  [PATCH] ppc32: ppc4xx_pic - add acknowledge wh...
# 708080  [PATCH] ppc32: fix bogosity in process-freezin...
# 708081  [PATCH] SELinux: add support for NETLINK_KOBJE...
# 708082                     [PATCH] irda_device() oops fix
# 708083                     [PATCH] Fix dst_destroy() race
# 708084  [PATCH] net: don't call kmem_cache_create with...
# 708085                   [PATCH] Fix linux/atalk.h header
# 708086        [PATCH] meminfo: add Cached underflow check
# 708087  [PATCH] end_buffer_write_sync() avoid pointles...
# 708088    [PATCH] vmscan: pageout(): remove unneeded test
# 708089  [PATCH] oom-killer disable for iscsi/lvm2/mult...
# 708090  [PATCH] filemap_getpage can block when MAP_NON...
# 708091  [PATCH] r128_state.c: break missing in switch ...
# 708092  [PATCH] SELinux: fix bug in Netlink message ty...
# 708093  [PATCH] fix Bug 4395: modprobe bttv freezes th...
# 708094                  [PATCH] Fix get_compat_sigevent()
# 708095           [PATCH] fix crash in entry.S restore_all
# 708096                               [PATCH] Fix acl Oops
# 708097  [PATCH] re-export cancel_rearming_delayed_work...
# 708098  [PATCH] crypto: call zlib end functions on def...
# 708099  [PATCH] arm: add comment about max_low_pfn/max...
# 708100     [PATCH] arm: add comment about dma_supported()
# 708101             [PATCH] arm: fix help text for ixdp465
# 708102                   [PATCH] arm: fix SIGBUS handling
# 708103  [PATCH] Avoid deadlock in sync_page_io by usin...
# 708104                          [PATCH] mmtimer build fix
# 708105                                   Linux-2.6.12-rc2
#
#                                                   message  \
# 0                                        Linux 4.14-rc8\n
# 1       Merge branch 'x86-urgent-for-linus' of git://g...
# 2       Merge branch 'ras-urgent-for-linus' of git://g...
# 3       Merge branch 'perf-urgent-for-linus' of git://...
# 4       Merge branch 'irq-urgent-for-linus' of git://g...
# 5       Merge branch 'core-urgent-for-linus' of git://...
# 6       Merge tag 'enforcement-4.14-rc8' of git://git....
# 7       x86/module: Detect and skip invalid relocation...
# 8       Merge branch 'fixes' of git://git.armlinux.org...
# 9       Merge tag 'for-linus' of git://git.kernel.org/...
# 10      Merge tag 'armsoc-fixes' of git://git.kernel.o...
# 11      Merge tag 'mips_fixes_4.14' of git://git.kerne...
# 12      objtool: Prevent GCC from merging annotate_unr...
# 13      Revert "x86/mm: Stop calling leave_mm() in idl...
# 14      Documentation: Add Frank Rowand to list of enf...
# 15      doc: add Willy Tarreau to the list of enforcem...
# 16      tools/headers: Synchronize kernel ABI headers\...
# 17      objtool: Resync objtool's instruction decoder ...
# 18      Merge branch 'linus' into core/urgent, to pick...
# 19      Merge branch 'for-linus' of git://git.kernel.o...
# 20      Merge tag 'clk-fixes-for-linus' of git://git.k...
# 21      Input: sparse-keymap - send sync event for KE_...
# 22      Input: ar1021_i2c - set INPUT_PROP_DIRECT\n\nI...
# 23      Merge git://git.kernel.org/pub/scm/linux/kerne...
# 24      Merge tag 'scsi-fixes' of git://git.kernel.org...
# 25      arch/tile: Implement ->set_state_oneshot_stopp...
# 26      Merge tag 'powerpc-4.14-6' of git://git.kernel...
# 27      Merge tag 'mmc-v4.14-rc4-3' of git://git.kerne...
# 28      Merge tag 'drm-fixes-for-v4.14-rc8' of git://p...
# 29      Merge git://git.kernel.org/pub/scm/linux/kerne...
# ...                                                   ...
# 708076  [PATCH] ppc32: fix single-stepping of emulated...
# 708077  [PATCH] ppc32: oops on kernel altivec assist e...
# 708078  [PATCH] ppc32: improve timebase sync for SMP\n...
# 708079  [PATCH] ppc32: ppc4xx_pic - add acknowledge wh...
# 708080  [PATCH] ppc32: fix bogosity in process-freezin...
# 708081  [PATCH] SELinux: add support for NETLINK_KOBJE...
# 708082  [PATCH] irda_device() oops fix\n\nAcked-by: "D...
# 708083  [PATCH] Fix dst_destroy() race\n\nWhen we are ...
# 708084  [PATCH] net: don't call kmem_cache_create with...
# 708085  [PATCH] Fix linux/atalk.h header\n\nThis recen...
# 708086  [PATCH] meminfo: add Cached underflow check\n\...
# 708087  [PATCH] end_buffer_write_sync() avoid pointles...
# 708088  [PATCH] vmscan: pageout(): remove unneeded tes...
# 708089  [PATCH] oom-killer disable for iscsi/lvm2/mult...
# 708090  [PATCH] filemap_getpage can block when MAP_NON...
# 708091  [PATCH] r128_state.c: break missing in switch ...
# 708092  [PATCH] SELinux: fix bug in Netlink message ty...
# 708093  [PATCH] fix Bug 4395: modprobe bttv freezes th...
# 708094  [PATCH] Fix get_compat_sigevent()\n\nI have no...
# 708095  [PATCH] fix crash in entry.S restore_all\n\nFi...
# 708096  [PATCH] Fix acl Oops\n\n\r)\n\n\nFrom: Andreas...
# 708097  [PATCH] re-export cancel_rearming_delayed_work...
# 708098  [PATCH] crypto: call zlib end functions on def...
# 708099  [PATCH] arm: add comment about max_low_pfn/max...
# 708100  [PATCH] arm: add comment about dma_supported()...
# 708101  [PATCH] arm: fix help text for ixdp465\n\n\r)\...
# 708102  [PATCH] arm: fix SIGBUS handling\n\n\r)\n\n\nF...
# 708103  [PATCH] Avoid deadlock in sync_page_io by usin...
# 708104  [PATCH] mmtimer build fix\n\nSigned-off-by: Ch...
# 708105  Linux-2.6.12-rc2\n\nInitial git repository bui...
#
#                                                     files
# 0                                                Makefile
# 1
# 2
# 3
# 4
# 5
# 6
# 7                                arch/x86/kernel/module.c
# 8
# 9
# 10
# 11
# 12                               include/linux/compiler.h
# 13      arch/ia64/include/asm/acpi.h,arch/x86/include/...
# 14      Documentation/process/kernel-enforcement-state...
# 15      Documentation/process/kernel-enforcement-state...
# 16      include/uapi/sound/asound.h,tools/arch/x86/inc...
# 17      tools/objtool/arch/x86/insn/gen-insn-attr-x86.awk
# 18
# 19
# 20
# 21                          drivers/input/sparse-keymap.c
# 22                 drivers/input/touchscreen/ar1021_i2c.c
# 23
# 24
# 25                                arch/tile/kernel/time.c
# 26
# 27
# 28
# 29
# ...                                                   ...
# 708076                            arch/ppc/kernel/traps.c
# 708077                            arch/ppc/kernel/traps.c
# 708078                      arch/ppc/platforms/pmac_smp.c
# 708079                       arch/ppc/syslib/ppc4xx_pic.c
# 708080                           arch/ppc/kernel/signal.c
# 708081  security/selinux/hooks.c,security/selinux/incl...
# 708082                             net/irda/irda_device.c
# 708083                                     net/core/dst.c
# 708084                                    net/core/sock.c
# 708085                              include/linux/atalk.h
# 708086                                fs/proc/proc_misc.c
# 708087                                        fs/buffer.c
# 708088                                        mm/vmscan.c
# 708089    fs/proc/base.c,include/linux/mm.h,mm/oom_kill.c
# 708090                                       mm/filemap.c
# 708091                      drivers/char/drm/r128_state.c
# 708092                        security/selinux/nlmsgtab.c
# 708093                   drivers/media/video/bttv-cards.c
# 708094                                    kernel/compat.c
# 708095  arch/i386/kernel/entry.S,arch/i386/kernel/proc...
# 708096                        fs/ext2/acl.c,fs/ext3/acl.c
# 708097       include/linux/workqueue.h,kernel/workqueue.c
# 708098                                   crypto/deflate.c
# 708099                                 arch/arm/mm/init.c
# 708100                      include/asm-arm/dma-mapping.h
# 708101                       arch/arm/mach-ixp4xx/Kconfig
# 708102                                arch/arm/mm/fault.c
# 708103                                    drivers/md/md.c
# 708104                             drivers/char/mmtimer.c
# 708105
#
# [708106 rows x 10 columns]
