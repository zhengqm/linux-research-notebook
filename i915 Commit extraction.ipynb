# %%
from git import Repo
import pandas as pd

# %%
def changed_files(c):
    if len(c.parents) != 1:
        return ""
    return ','.join([d.a_path for d in c.diff(c.parents[0])])

# %%
repo_dir = "D:\drm-intel"
first_run = True

if first_run:
    repo = Repo(repo_dir)
    commits = list(repo.iter_commits("drm-intel-next-queued"))
    def isValid(c):
        try:
            c.authored_datetime, c.committed_datetime
            return True
        except:
            return False
    commit_list = map(lambda c: (c.hexsha, c.authored_datetime, c.author.name, c.author.email, c.committed_datetime, c.committer.name, c.committer.email, c.summary, c.message, changed_files(c)), filter(lambda c: isValid(c), commits))
    commit_df = pd.DataFrame(commit_list, columns='hexsha,authored_datetime,author_name,author_email,committed_datetime,committer_name,committer_email,summary,message,files'.split(','))
    commit_df['authored_datetime'] = pd.to_datetime(commit_df['authored_datetime'], utc=True)
    commit_df['committed_datetime'] = pd.to_datetime(commit_df['committed_datetime'], utc=True)
    commit_df.to_pickle("i915.pkl")
else:
    commit_df = pd.read_pickle("i915.pkl")

# %%
print "hello"
# Out:
# hello

# %%
pd.read_pickle("i915.pkl")
# Out:
#                                           hexsha         authored_datetime  \
# 0       c218ee03b9315073ce43992792554dafa0626eb8 2018-01-06 10:56:18+00:00
# 1       ab062639edb0412daf6de540725276b9a5d217f9 2018-01-05 08:59:05+00:00
# 2       fe9a9da61c3ec33c7d3ad305c2c535edbcae1ddb 2018-01-04 23:51:42+00:00
# 3       a76050a4837860fcadb6ca11d69d41e08f4090d8 2018-01-03 19:03:45+00:00
# 4       82e07602d22ab45cd90e31b62a87f0fa37ca428f 2018-01-04 16:38:42+00:00
# 5       c68ce69910e3b292afc138e12725399d3b0fb347 2018-01-02 19:25:00+00:00
# 6       6f25d0be180f5b4713c6fb5a6619fe11dd1dacd9 2018-01-02 21:20:25+00:00
# 7       c24f0c1de481c1c0f914e937f409bac2c90b90b3 2018-01-02 21:20:24+00:00
# 8       2221c5b7ddfae1ed1ca8b21a9092d0878281293a 2018-01-02 15:12:27+00:00
# 9       ce01b173773a09e2b5d3007c26d11cbd7737c3fe 2018-01-02 15:12:26+00:00
# 10      83cc84c5a848748d4bb190bc179a7620491a925f 2018-01-02 15:12:25+00:00
# 11      65c475c6dd607226159a774d7c3d7ff4b6e00255 2018-01-02 15:12:31+00:00
# 12      f3c9d4075771b4fbaa0d793d2c875c61e2e1cb12 2018-01-02 15:12:34+00:00
# 13      693cfbf0589040536c673d6ed3d262ea3ecf9aea 2018-01-02 15:12:33+00:00
# 14      42232213614ddbef854ef368092e39c4e8347877 2018-01-02 15:12:32+00:00
# 15      27ec1843169973fbdf224d831e2a40f441407ab0 2018-01-02 15:12:17+00:00
# 16      9861b6682804a9db82600e0adf592bfa6deec377 2017-12-23 11:04:07+00:00
# 17      85a9c0bc0888be8b140de06ae6486208bc1424f9 2017-12-23 11:04:06+00:00
# 18      ce6e21370d5cacff3cd06c997af65316e7bba577 2017-11-20 04:23:47+00:00
# 19      35954e88bc5091ef82134e8c99c5bcc3b4c6772a 2017-11-07 18:38:23+00:00
# 20      c8dae55a8ced625038d52d26e48273707fab2688 2017-12-20 10:50:17+00:00
# 21      53421c2fe99ce16838639ad89d772d914a119a49 2017-12-04 23:22:10+00:00
# 22      cfe4982ca488016d697cf0769ae70c9a78060c0d 2017-12-22 19:41:50+00:00
# 23      c1bf272857896d09fdaba0aa119f1f6240cb5cb9 2017-12-22 18:25:21+00:00
# 24      2d453c7895c0ca6028500050ff9305c70fd7252f 2017-12-22 14:19:59+00:00
# 25      193a98dc7cc4770580ebcd0fa64a6c23a50093af 2017-12-22 13:27:42+00:00
# 26      e329ef67a7b06a3ab9b28fca4464760d4d7f8d47 2017-12-22 18:13:23+00:00
# 27      757fffcfdffb6c0dd46c1b264091c36b4e5a86ae 2017-11-13 13:36:22+00:00
# 28      6481d5ed076e69db83ca75e751ad492a6fb669a7 2017-12-21 20:24:32+00:00
# 29      ad8059cf2e33042be31b09d44fd3e61ac9c50219 2017-12-08 21:37:38+00:00
# ...                                          ...                       ...
# 723134  6c26e03b2db4b66d79bfb774628c1fc9b458b943 2005-04-16 22:24:17+00:00
# 723135  e378cc16b0d3c1610857c4444345907020e03ece 2005-04-16 22:24:17+00:00
# 723136  6460b4cceba0181308042c8d8794eb679bfa22e5 2005-04-16 22:24:16+00:00
# 723137  35b535d9cc8dce79c3b72f47c4417c3159d7a8c9 2005-04-16 22:24:15+00:00
# 723138  16acbc624e2b7b750570cb672341d05a816051f4 2005-04-16 22:24:14+00:00
# 723139  0c9b79429c83a404a04908be65baa9d97836bbb6 2005-04-16 22:24:13+00:00
# 723140  7e5c6bc0a600c49e5922591ad41ff41987f54eb4 2005-04-16 22:24:11+00:00
# 723141  6775cab98b89b2caa10dce4b07e2c81999e45517 2005-04-16 22:24:10+00:00
# 723142  2a27805127aee1e7e62854bcf9ca8c355c23b73e 2005-04-16 22:24:09+00:00
# 723143  9f3786dc8b1d6229dbe76e364323f0d787e7a0ea 2005-04-16 22:24:09+00:00
# 723144  4c4c402d6caba5d938ffbbb49961659ecac709d4 2005-04-16 22:24:08+00:00
# 723145  76c3073a888ae7f4790a146784bb5c34fc24b9d2 2005-04-16 22:24:07+00:00
# 723146  323aca6c0bda611d0f31b3234d9fe291d31a9207 2005-04-16 22:24:06+00:00
# 723147  79befd0c08c4766f8fa27e37ac2a70e40840a56a 2005-04-16 22:24:05+00:00
# 723148  d345734267dbec642f4e34a9d392d2fd85b5fa9b 2005-04-16 22:24:05+00:00
# 723149  41aac24f8fb5a21ff3d0f6f56f85fad3cf0e88a9 2005-04-16 22:24:04+00:00
# 723150  388c69789a2a2e50965e805e3e641418082b352c 2005-04-16 22:24:03+00:00
# 723151  1db7fc75a410d9a15cbc58a9b073a688669c6d42 2005-04-16 22:24:02+00:00
# 723152  51410d3c53d85da0f24277f9580cbec1260ffc8f 2005-04-16 22:24:01+00:00
# 723153  5df240826c90afdc7956f55a004ea6b702df9203 2005-04-16 22:24:01+00:00
# 723154  e493073d8d053429fbb42331b57a95dd0d61cadb 2005-04-16 22:24:00+00:00
# 723155  81ddef77bb774e771db8588b937665cd38f40cee 2005-04-16 22:23:59+00:00
# 723156  9ffb7146f0aa9c0070cda3d8701b0a89e34913d1 2005-04-16 22:23:58+00:00
# 723157  d42ce812b8a32adddeee3a692005f82f95ff15a3 2005-04-16 22:23:57+00:00
# 723158  7a228aaa879c119c9fb9b9d7e062ac13cb1a9079 2005-04-16 22:23:57+00:00
# 723159  7aa52f5128b06d1df9b2ee65c06d401af27da0a4 2005-04-16 22:23:56+00:00
# 723160  2d137c24e9f433e37ffd10b3d5f418157589a8d2 2005-04-16 22:23:55+00:00
# 723161  baaa2c512dc1c47e3afeb9d558c5323c9240bd21 2005-04-16 22:23:54+00:00
# 723162  8d38eadb7a97f265f7b3a9e8a30df358c3a546c8 2005-04-16 22:23:53+00:00
# 723163  1da177e4c3f41524e886b7f1b8a0c1fc7321cac2 2005-04-16 22:20:36+00:00
#
#                      author_name                    author_email  \
# 0                   Chris Wilson        chris@chris-wilson.co.uk
# 1                Kenneth Graunke           kenneth@whitecape.org
# 2                Anusha Srivatsa       anusha.srivatsa@intel.com
# 3                Anusha Srivatsa       anusha.srivatsa@intel.com
# 4                   Chris Wilson        chris@chris-wilson.co.uk
# 5                   Chris Wilson        chris@chris-wilson.co.uk
# 6           Sujaritha Sundaresan  sujaritha.sundaresan@intel.com
# 7           Sujaritha Sundaresan  sujaritha.sundaresan@intel.com
# 8                   Chris Wilson        chris@chris-wilson.co.uk
# 9                   Chris Wilson        chris@chris-wilson.co.uk
# 10                  Chris Wilson        chris@chris-wilson.co.uk
# 11                  Chris Wilson        chris@chris-wilson.co.uk
# 12                  Chris Wilson        chris@chris-wilson.co.uk
# 13                  Chris Wilson        chris@chris-wilson.co.uk
# 14                  Chris Wilson        chris@chris-wilson.co.uk
# 15                  Chris Wilson        chris@chris-wilson.co.uk
# 16                  Chris Wilson        chris@chris-wilson.co.uk
# 17                  Chris Wilson        chris@chris-wilson.co.uk
# 18                 C, Ramalingam          ramalingam.c@intel.com
# 19                 C, Ramalingam          ramalingam.c@intel.com
# 20                 Hans de Goede         j.w.r.degoede@gmail.com
# 21               Lucas De Marchi        lucas.demarchi@intel.com
# 22                  Rodrigo Vivi          rodrigo.vivi@intel.com
# 23                  Chris Wilson        chris@chris-wilson.co.uk
# 24                  Chris Wilson        chris@chris-wilson.co.uk
# 25                  Chris Wilson        chris@chris-wilson.co.uk
# 26                  Rodrigo Vivi          rodrigo.vivi@intel.com
# 27                 Ville Syrjälä   ville.syrjala@linux.intel.com
# 28                 Ville Syrjälä   ville.syrjala@linux.intel.com
# 29                 Ville Syrjälä   ville.syrjala@linux.intel.com
# ...                          ...                             ...
# 723134            Paul Mackerras                paulus@samba.org
# 723135            Paul Mackerras                paulus@samba.org
# 723136            Paul Mackerras                paulus@samba.org
# 723137          Eugene Surovegin                 ebs@ebshome.net
# 723138            Paul Mackerras                paulus@samba.org
# 723139              James Morris              jmorris@redhat.com
# 723140           Jean Tourrilhes                   jt@hpl.hp.com
# 723141                Herbert Xu     herbert@gondor.apana.org.au
# 723142  Arnaldo Carvalho de Melo           acme@conectiva.com.br
# 723143           David S. Miller             davem@davemloft.net
# 723144              Martin Hicks                    mort@sgi.com
# 723145             akpm@osdl.org                   akpm@osdl.org
# 723146             akpm@osdl.org                   akpm@osdl.org
# 723147          Andrea Arcangeli                  andrea@suse.de
# 723148                Jeff Moyer               jmoyer@redhat.com
# 723149               Dave Airlie                airlied@linux.ie
# 723150              James Morris              jmorris@redhat.com
# 723151             akpm@osdl.org                   akpm@osdl.org
# 723152           David S. Miller             davem@davemloft.net
# 723153              Stas Sergeev                   stsp@aknet.ru
# 723154             akpm@osdl.org                   akpm@osdl.org
# 723155           James Bottomley    James.Bottomley@SteelEye.com
# 723156        Artem B. Bityuckiy          dedekind@infradead.org
# 723157             akpm@osdl.org                   akpm@osdl.org
# 723158             akpm@osdl.org                   akpm@osdl.org
# 723159             akpm@osdl.org                   akpm@osdl.org
# 723160             akpm@osdl.org                   akpm@osdl.org
# 723161                Neil Brown           neilb@cse.unsw.edu.au
# 723162         Christoph Lameter           clameter@engr.sgi.com
# 723163            Linus Torvalds        torvalds@ppc970.osdl.org
#
#               committed_datetime  committer_name  \
# 0      2018-01-08 09:16:02+00:00    Chris Wilson
# 1      2018-01-05 17:42:33+00:00    Rodrigo Vivi
# 2      2018-01-05 00:29:12+00:00    Rodrigo Vivi
# 3      2018-01-04 22:45:07+00:00    Rodrigo Vivi
# 4      2018-01-04 18:48:53+00:00    Chris Wilson
# 5      2018-01-03 17:48:00+00:00    Chris Wilson
# 6      2018-01-03 14:02:12+00:00    Chris Wilson
# 7      2018-01-03 14:02:10+00:00    Chris Wilson
# 8      2018-01-03 12:09:46+00:00    Chris Wilson
# 9      2018-01-03 12:09:44+00:00    Chris Wilson
# 10     2018-01-03 12:05:41+00:00    Chris Wilson
# 11     2018-01-03 11:42:33+00:00    Chris Wilson
# 12     2018-01-03 11:02:43+00:00    Chris Wilson
# 13     2018-01-03 11:01:38+00:00    Chris Wilson
# 14     2018-01-03 11:01:05+00:00    Chris Wilson
# 15     2018-01-03 11:00:11+00:00    Chris Wilson
# 16     2018-01-02 15:30:40+00:00    Chris Wilson
# 17     2018-01-02 15:27:36+00:00    Chris Wilson
# 18     2017-12-28 16:55:10+00:00    Rodrigo Vivi
# 19     2017-12-28 16:55:03+00:00    Rodrigo Vivi
# 20     2017-12-23 18:59:43+00:00   Hans de Goede
# 21     2017-12-22 21:50:18+00:00    Rodrigo Vivi
# 22     2017-12-22 19:41:50+00:00    Rodrigo Vivi
# 23     2017-12-22 19:02:52+00:00    Chris Wilson
# 24     2017-12-22 18:34:05+00:00    Chris Wilson
# 25     2017-12-22 18:32:51+00:00    Chris Wilson
# 26     2017-12-22 18:13:23+00:00    Rodrigo Vivi
# 27     2017-12-22 12:29:42+00:00   Ville Syrjälä
# 28     2017-12-22 12:23:14+00:00   Ville Syrjälä
# 29     2017-12-22 12:22:48+00:00   Ville Syrjälä
# ...                          ...             ...
# 723134 2005-04-16 22:24:17+00:00  Linus Torvalds
# 723135 2005-04-16 22:24:17+00:00  Linus Torvalds
# 723136 2005-04-16 22:24:16+00:00  Linus Torvalds
# 723137 2005-04-16 22:24:15+00:00  Linus Torvalds
# 723138 2005-04-16 22:24:14+00:00  Linus Torvalds
# 723139 2005-04-16 22:24:13+00:00  Linus Torvalds
# 723140 2005-04-16 22:24:11+00:00  Linus Torvalds
# 723141 2005-04-16 22:24:10+00:00  Linus Torvalds
# 723142 2005-04-16 22:24:09+00:00  Linus Torvalds
# 723143 2005-04-16 22:24:09+00:00  Linus Torvalds
# 723144 2005-04-16 22:24:08+00:00  Linus Torvalds
# 723145 2005-04-16 22:24:07+00:00  Linus Torvalds
# 723146 2005-04-16 22:24:06+00:00  Linus Torvalds
# 723147 2005-04-16 22:24:05+00:00  Linus Torvalds
# 723148 2005-04-16 22:24:05+00:00  Linus Torvalds
# 723149 2005-04-16 22:24:04+00:00  Linus Torvalds
# 723150 2005-04-16 22:24:03+00:00  Linus Torvalds
# 723151 2005-04-16 22:24:02+00:00  Linus Torvalds
# 723152 2005-04-16 22:24:01+00:00  Linus Torvalds
# 723153 2005-04-16 22:24:01+00:00  Linus Torvalds
# 723154 2005-04-16 22:24:00+00:00  Linus Torvalds
# 723155 2005-04-16 22:23:59+00:00  Linus Torvalds
# 723156 2005-04-16 22:23:58+00:00  Linus Torvalds
# 723157 2005-04-16 22:23:57+00:00  Linus Torvalds
# 723158 2005-04-16 22:23:57+00:00  Linus Torvalds
# 723159 2005-04-16 22:23:56+00:00  Linus Torvalds
# 723160 2005-04-16 22:23:55+00:00  Linus Torvalds
# 723161 2005-04-16 22:23:54+00:00  Linus Torvalds
# 723162 2005-04-16 22:23:53+00:00  Linus Torvalds
# 723163 2005-04-16 22:20:36+00:00  Linus Torvalds
#
#                       committer_email  \
# 0            chris@chris-wilson.co.uk
# 1              rodrigo.vivi@intel.com
# 2              rodrigo.vivi@intel.com
# 3              rodrigo.vivi@intel.com
# 4            chris@chris-wilson.co.uk
# 5            chris@chris-wilson.co.uk
# 6            chris@chris-wilson.co.uk
# 7            chris@chris-wilson.co.uk
# 8            chris@chris-wilson.co.uk
# 9            chris@chris-wilson.co.uk
# 10           chris@chris-wilson.co.uk
# 11           chris@chris-wilson.co.uk
# 12           chris@chris-wilson.co.uk
# 13           chris@chris-wilson.co.uk
# 14           chris@chris-wilson.co.uk
# 15           chris@chris-wilson.co.uk
# 16           chris@chris-wilson.co.uk
# 17           chris@chris-wilson.co.uk
# 18             rodrigo.vivi@intel.com
# 19             rodrigo.vivi@intel.com
# 20                hdegoede@redhat.com
# 21             rodrigo.vivi@intel.com
# 22             rodrigo.vivi@intel.com
# 23           chris@chris-wilson.co.uk
# 24           chris@chris-wilson.co.uk
# 25           chris@chris-wilson.co.uk
# 26             rodrigo.vivi@intel.com
# 27      ville.syrjala@linux.intel.com
# 28      ville.syrjala@linux.intel.com
# 29      ville.syrjala@linux.intel.com
# ...                               ...
# 723134       torvalds@ppc970.osdl.org
# 723135       torvalds@ppc970.osdl.org
# 723136       torvalds@ppc970.osdl.org
# 723137       torvalds@ppc970.osdl.org
# 723138       torvalds@ppc970.osdl.org
# 723139       torvalds@ppc970.osdl.org
# 723140       torvalds@ppc970.osdl.org
# 723141       torvalds@ppc970.osdl.org
# 723142       torvalds@ppc970.osdl.org
# 723143       torvalds@ppc970.osdl.org
# 723144       torvalds@ppc970.osdl.org
# 723145       torvalds@ppc970.osdl.org
# 723146       torvalds@ppc970.osdl.org
# 723147       torvalds@ppc970.osdl.org
# 723148       torvalds@ppc970.osdl.org
# 723149       torvalds@ppc970.osdl.org
# 723150       torvalds@ppc970.osdl.org
# 723151       torvalds@ppc970.osdl.org
# 723152       torvalds@ppc970.osdl.org
# 723153       torvalds@ppc970.osdl.org
# 723154       torvalds@ppc970.osdl.org
# 723155       torvalds@ppc970.osdl.org
# 723156       torvalds@ppc970.osdl.org
# 723157       torvalds@ppc970.osdl.org
# 723158       torvalds@ppc970.osdl.org
# 723159       torvalds@ppc970.osdl.org
# 723160       torvalds@ppc970.osdl.org
# 723161       torvalds@ppc970.osdl.org
# 723162       torvalds@ppc970.osdl.org
# 723163       torvalds@ppc970.osdl.org
#
#                                                   summary  \
# 0       drm/i915: Don't adjust priority on an already ...
# 1       drm/i915: Whitelist SLICE_COMMON_ECO_CHICKEN1 ...
# 2                   drm/i915/dmc: DMC 1.07 for Cannonlake
# 3                drm/i915/glk: Disable Guc and HuC on GLK
# 4         drm/i915: Pass DMA_ATTR_NO_WARN to dma_map_sg()
# 5       drm/i915: Assert we do not try to wait on an i...
# 6       drm/i915/guc : GEM_BUG_ON on invoking GuC rese...
# 7       drm/i915/guc : Decoupling ADS and logs from su...
# 8       drm/i915/execlists: Reduce list_for_each_safe+...
# 9       drm/i915/execlists: Assert there are no simple...
# 10      drm/i915: Assert all signalers we depended on ...
# 11      drm/i915: Hold rpm wakeref for modifying the g...
# 12            drm/i915/execlists: Tidy enabling execlists
# 13      drm/i915/execlists: Record elsp offset during ...
# 14      drm/i915/execlists: Clear context-switch inter...
# 15      drm/i915: Delete defunct i915_gem_request_assi...
# 16      drm/i915/selftests: Allow random array allocat...
# 17      drm/i915/selftests: Tweak igt_ggtt_page to spe...
# 18            i915/drrs/debugfs: psr status info addition
# 19                 drm/i915: Runtime disable for eDP DRRS
# 20             drm/i915/vlv: Add cdclk workaround for DSI
# 21      drm/i915: Apply Display WA #1183 on skl, kbl, ...
# 22               drm/i915: Update DRIVER_DATE to 20171222
# 23             drm/i915: Show HWSP in intel_engine_dump()
# 24      drm/i915: Assert that the request is on the ex...
# 25      drm/i915/execlists: Show preemption progress i...
# 26      Merge tag 'gvt-next-2017-12-22' of https://git...
# 27      drm/i915: Put all non-blocking modesets onto a...
# 28      drm/i915: Disable GMBUS clock gating around GM...
# 29      drm/i915: Clean up the PNV bit banging vs. GMB...
# ...                                                   ...
# 723134  [PATCH] ppc32: fix single-stepping of emulated...
# 723135  [PATCH] ppc32: oops on kernel altivec assist e...
# 723136       [PATCH] ppc32: improve timebase sync for SMP
# 723137  [PATCH] ppc32: ppc4xx_pic - add acknowledge wh...
# 723138  [PATCH] ppc32: fix bogosity in process-freezin...
# 723139  [PATCH] SELinux: add support for NETLINK_KOBJE...
# 723140                     [PATCH] irda_device() oops fix
# 723141                     [PATCH] Fix dst_destroy() race
# 723142  [PATCH] net: don't call kmem_cache_create with...
# 723143                   [PATCH] Fix linux/atalk.h header
# 723144        [PATCH] meminfo: add Cached underflow check
# 723145  [PATCH] end_buffer_write_sync() avoid pointles...
# 723146    [PATCH] vmscan: pageout(): remove unneeded test
# 723147  [PATCH] oom-killer disable for iscsi/lvm2/mult...
# 723148  [PATCH] filemap_getpage can block when MAP_NON...
# 723149  [PATCH] r128_state.c: break missing in switch ...
# 723150  [PATCH] SELinux: fix bug in Netlink message ty...
# 723151  [PATCH] fix Bug 4395: modprobe bttv freezes th...
# 723152                  [PATCH] Fix get_compat_sigevent()
# 723153           [PATCH] fix crash in entry.S restore_all
# 723154                               [PATCH] Fix acl Oops
# 723155  [PATCH] re-export cancel_rearming_delayed_work...
# 723156  [PATCH] crypto: call zlib end functions on def...
# 723157  [PATCH] arm: add comment about max_low_pfn/max...
# 723158     [PATCH] arm: add comment about dma_supported()
# 723159             [PATCH] arm: fix help text for ixdp465
# 723160                   [PATCH] arm: fix SIGBUS handling
# 723161  [PATCH] Avoid deadlock in sync_page_io by usin...
# 723162                          [PATCH] mmtimer build fix
# 723163                                   Linux-2.6.12-rc2
#
#                                                   message  \
# 0       drm/i915: Don't adjust priority on an already ...
# 1       drm/i915: Whitelist SLICE_COMMON_ECO_CHICKEN1 ...
# 2       drm/i915/dmc: DMC 1.07 for Cannonlake\n\nThere...
# 3       drm/i915/glk: Disable Guc and HuC on GLK\n\nSi...
# 4       drm/i915: Pass DMA_ATTR_NO_WARN to dma_map_sg(...
# 5       drm/i915: Assert we do not try to wait on an i...
# 6       drm/i915/guc : GEM_BUG_ON on invoking GuC rese...
# 7       drm/i915/guc : Decoupling ADS and logs from su...
# 8       drm/i915/execlists: Reduce list_for_each_safe+...
# 9       drm/i915/execlists: Assert there are no simple...
# 10      drm/i915: Assert all signalers we depended on ...
# 11      drm/i915: Hold rpm wakeref for modifying the g...
# 12      drm/i915/execlists: Tidy enabling execlists\n\...
# 13      drm/i915/execlists: Record elsp offset during ...
# 14      drm/i915/execlists: Clear context-switch inter...
# 15      drm/i915: Delete defunct i915_gem_request_assi...
# 16      drm/i915/selftests: Allow random array allocat...
# 17      drm/i915/selftests: Tweak igt_ggtt_page to spe...
# 18      i915/drrs/debugfs: psr status info addition\n\...
# 19      drm/i915: Runtime disable for eDP DRRS\n\nDebu...
# 20      drm/i915/vlv: Add cdclk workaround for DSI\n\n...
# 21      drm/i915: Apply Display WA #1183 on skl, kbl, ...
# 22      drm/i915: Update DRIVER_DATE to 20171222\n\nSi...
# 23      drm/i915: Show HWSP in intel_engine_dump()\n\n...
# 24      drm/i915: Assert that the request is on the ex...
# 25      drm/i915/execlists: Show preemption progress i...
# 26      Merge tag 'gvt-next-2017-12-22' of https://git...
# 27      drm/i915: Put all non-blocking modesets onto a...
# 28      drm/i915: Disable GMBUS clock gating around GM...
# 29      drm/i915: Clean up the PNV bit banging vs. GMB...
# ...                                                   ...
# 723134  [PATCH] ppc32: fix single-stepping of emulated...
# 723135  [PATCH] ppc32: oops on kernel altivec assist e...
# 723136  [PATCH] ppc32: improve timebase sync for SMP\n...
# 723137  [PATCH] ppc32: ppc4xx_pic - add acknowledge wh...
# 723138  [PATCH] ppc32: fix bogosity in process-freezin...
# 723139  [PATCH] SELinux: add support for NETLINK_KOBJE...
# 723140  [PATCH] irda_device() oops fix\n\nAcked-by: "D...
# 723141  [PATCH] Fix dst_destroy() race\n\nWhen we are ...
# 723142  [PATCH] net: don't call kmem_cache_create with...
# 723143  [PATCH] Fix linux/atalk.h header\n\nThis recen...
# 723144  [PATCH] meminfo: add Cached underflow check\n\...
# 723145  [PATCH] end_buffer_write_sync() avoid pointles...
# 723146  [PATCH] vmscan: pageout(): remove unneeded tes...
# 723147  [PATCH] oom-killer disable for iscsi/lvm2/mult...
# 723148  [PATCH] filemap_getpage can block when MAP_NON...
# 723149  [PATCH] r128_state.c: break missing in switch ...
# 723150  [PATCH] SELinux: fix bug in Netlink message ty...
# 723151  [PATCH] fix Bug 4395: modprobe bttv freezes th...
# 723152  [PATCH] Fix get_compat_sigevent()\n\nI have no...
# 723153  [PATCH] fix crash in entry.S restore_all\n\nFi...
# 723154  [PATCH] Fix acl Oops\n\n\r)\n\n\nFrom: Andreas...
# 723155  [PATCH] re-export cancel_rearming_delayed_work...
# 723156  [PATCH] crypto: call zlib end functions on def...
# 723157  [PATCH] arm: add comment about max_low_pfn/max...
# 723158  [PATCH] arm: add comment about dma_supported()...
# 723159  [PATCH] arm: fix help text for ixdp465\n\n\r)\...
# 723160  [PATCH] arm: fix SIGBUS handling\n\n\r)\n\n\nF...
# 723161  [PATCH] Avoid deadlock in sync_page_io by usin...
# 723162  [PATCH] mmtimer build fix\n\nSigned-off-by: Ch...
# 723163  Linux-2.6.12-rc2\n\nInitial git repository bui...
#
#                                                     files
# 0       drivers/gpu/drm/i915/i915_gem.c,drivers/gpu/dr...
# 1       drivers/gpu/drm/i915/i915_reg.h,drivers/gpu/dr...
# 2                        drivers/gpu/drm/i915/intel_csr.c
# 3       drivers/gpu/drm/i915/intel_guc_fw.c,drivers/gp...
# 4                     drivers/gpu/drm/i915/i915_gem_gtt.c
# 5                drivers/gpu/drm/i915/intel_breadcrumbs.c
# 6                     drivers/gpu/drm/i915/intel_uncore.c
# 7       drivers/gpu/drm/i915/Makefile,drivers/gpu/drm/...
# 8                        drivers/gpu/drm/i915/intel_lrc.c
# 9                        drivers/gpu/drm/i915/intel_lrc.c
# 10      drivers/gpu/drm/i915/i915_gem_request.c,driver...
# 11                    drivers/gpu/drm/i915/i915_debugfs.c
# 12                       drivers/gpu/drm/i915/intel_lrc.c
# 13                       drivers/gpu/drm/i915/intel_lrc.c
# 14                       drivers/gpu/drm/i915/intel_lrc.c
# 15                drivers/gpu/drm/i915/i915_gem_request.h
# 16           drivers/gpu/drm/i915/selftests/i915_random.c
# 17          drivers/gpu/drm/i915/selftests/i915_gem_gtt.c
# 18                    drivers/gpu/drm/i915/i915_debugfs.c
# 19                    drivers/gpu/drm/i915/i915_debugfs.c
# 20                     drivers/gpu/drm/i915/intel_cdclk.c
# 21      drivers/gpu/drm/i915/i915_reg.h,drivers/gpu/dr...
# 22                        drivers/gpu/drm/i915/i915_drv.h
# 23                 drivers/gpu/drm/i915/intel_engine_cs.c
# 24                drivers/gpu/drm/i915/i915_gem_request.c
# 25                       drivers/gpu/drm/i915/intel_lrc.c
# 26
# 27      drivers/gpu/drm/i915/i915_drv.h,drivers/gpu/dr...
# 28      drivers/gpu/drm/i915/i915_reg.h,drivers/gpu/dr...
# 29      drivers/gpu/drm/i915/i915_reg.h,drivers/gpu/dr...
# ...                                                   ...
# 723134                            arch/ppc/kernel/traps.c
# 723135                            arch/ppc/kernel/traps.c
# 723136                      arch/ppc/platforms/pmac_smp.c
# 723137                       arch/ppc/syslib/ppc4xx_pic.c
# 723138                           arch/ppc/kernel/signal.c
# 723139  security/selinux/hooks.c,security/selinux/incl...
# 723140                             net/irda/irda_device.c
# 723141                                     net/core/dst.c
# 723142                                    net/core/sock.c
# 723143                              include/linux/atalk.h
# 723144                                fs/proc/proc_misc.c
# 723145                                        fs/buffer.c
# 723146                                        mm/vmscan.c
# 723147    fs/proc/base.c,include/linux/mm.h,mm/oom_kill.c
# 723148                                       mm/filemap.c
# 723149                      drivers/char/drm/r128_state.c
# 723150                        security/selinux/nlmsgtab.c
# 723151                   drivers/media/video/bttv-cards.c
# 723152                                    kernel/compat.c
# 723153  arch/i386/kernel/entry.S,arch/i386/kernel/proc...
# 723154                        fs/ext2/acl.c,fs/ext3/acl.c
# 723155       include/linux/workqueue.h,kernel/workqueue.c
# 723156                                   crypto/deflate.c
# 723157                                 arch/arm/mm/init.c
# 723158                      include/asm-arm/dma-mapping.h
# 723159                       arch/arm/mach-ixp4xx/Kconfig
# 723160                                arch/arm/mm/fault.c
# 723161                                    drivers/md/md.c
# 723162                             drivers/char/mmtimer.c
# 723163
#
# [723164 rows x 10 columns]

# %%
commit_df[commit_df.files == ""]
# Out:
#                                           hexsha         authored_datetime  \
# 26      e329ef67a7b06a3ab9b28fca4464760d4d7f8d47 2017-12-22 18:13:23+00:00
# 72      2ef6765ccaab2c69470d7049d9a9bf6456a6e666 2017-12-18 08:29:37+00:00
# 80      07825e4b9311b11df02365a35cdf997d69426b29 2017-12-14 18:57:39+00:00
# 124     6647852abc1fd74e9c5e0dcf404ea4cb9c929630 2017-12-08 18:15:30+00:00
# 136     3f1f0b1c57dd617e9b0ded50efb8d6c011b85b20 2017-12-07 22:39:14+00:00
# 137     5c379b4f4fd0c97e7bd31b3523c7e5c2bdf4a9b6 2017-12-07 22:15:54+00:00
# 142     9c606cd4117a3c45e04a6616b1a0dbeb18eeee62 2017-12-06 20:28:22+00:00
# 355     0d7e76beaa92de8837af7d49a36058ee6cf8fe78 2017-12-06 00:46:14+00:00
# 391     c5dd52f653fa74f8f4771425c6db33609ad21258 2017-12-05 00:34:46+00:00
# 488     7b47c66cfa203288c43851260edeeb0fae56f692 2017-12-04 18:04:45+00:00
# 513     ca797d29cd63e7b71b4eea29aff3b1cefd1ecb59 2017-12-03 23:40:35+00:00
# 514     2c1c55cb75a9c72f9726fabb8c3607947711a8df 2017-12-03 19:38:52+00:00
# 516     87fc5c686ef3db9e58d2fd65e1bcc368ee6b1b76 2017-12-03 15:51:08+00:00
# 517     ae4806a38bc8db0b48e746445c41afd249568d68 2017-12-03 15:48:24+00:00
# 518     49a418d78378769cf78b8c645f7e469f4dae2bbd 2017-12-03 15:46:16+00:00
# 519     edef30980dc06bea547baefcfc8d910682b6e060 2017-12-02 22:32:13+00:00
# 521     2db767d9889cef087149a5eaa35c1497671fa40f 2017-12-02 01:04:20+00:00
# 522     788c1da05b73aee68ed98f05b577c308351f5619 2017-12-02 01:00:19+00:00
# 523     e1ba1c99dad92c5917b22b1047cf36e4426b124a 2017-12-02 00:39:12+00:00
# 524     4b1967c90af473e3a8bec00024758a3e676cea2d 2017-12-02 00:37:03+00:00
# 525     3b62de26cf5ef17340a0e986d3e53eb4f74f96d5 2017-12-01 21:31:31+00:00
# 526     185e788c84a95cb024cff98988bdeb09e619cd62 2017-12-01 21:16:15+00:00
# 527     7382fbdeae0d6dbd1c26ebf4a302f1ccf33d9882 2017-12-01 21:14:36+00:00
# 528     07f8ba7439f9c942d5bd7b63074e7a1528601713 2017-12-01 21:12:10+00:00
# 529     f8182f613c9887744eb469b1a3352636481cb395 2017-12-01 21:10:42+00:00
# 543     a0651c7fa2c088a605f63792279859608ed7f2c8 2017-12-01 13:40:17+00:00
# 544     ae753ee2771a1bacade56411bb98037b2545c929 2017-12-01 13:36:27+00:00
# 545     3c1c4ddffb58b9e10b3365764fe59546130b3f32 2017-12-01 13:14:22+00:00
# 546     5dc9cbc4f10d7bc5aaa17ec0accf4c6e24d9ecd6 2017-12-01 13:10:09+00:00
# 549     75f64f68afa165ebe139cca2adb4df0a229a06de 2017-12-01 13:05:45+00:00
# ...                                          ...                       ...
# 722234  235bd6140dad7c08261abdc1f8056485c5344a74 2005-05-04 14:06:38+00:00
# 722266  8800cea62025a5209d110c5fa5990429239d6eee 2005-05-04 00:24:08+00:00
# 722281  84e48b6d64fdc29586bc7d9329f986cdae591a80 2005-05-03 22:27:24+00:00
# 722336  27b030d58c8e72fc7a95187a791bd9406e350f02 2005-05-03 07:14:09+00:00
# 722529  1d651f3332340c232ff66b7f5bab66cb8903859f 2005-04-30 22:42:33+00:00
# 722533  49e7dc54cd4cbdb439ecc4e06214b0ca1a1a72b4 2005-04-30 20:34:21+00:00
# 722540  a6ad57fb4b5e9d68553f4440377b99f75588fa88 2005-04-29 22:08:34+00:00
# 722541  dd96a8e056e7b3e480197ff2cdf106b46455d779 2005-04-29 22:06:00+00:00
# 722596  2604f6da1afb56fae5930b58349e43a2b0345933 2005-04-28 23:09:57+00:00
# 722630  fc67b16ecaf6ebde04096030c268adddade023f1 2005-04-27 17:05:42+00:00
# 722636  97af11286d68e359f61579214ca7a7b4433fe458 2005-04-26 16:02:40+00:00
# 722637  1e14c33fe2e3409d9f34041859af52be6e4723af 2005-04-26 15:58:22+00:00
# 722651  99805f47dd0ede2e96f2c62c588a0d906811ed6d 2005-04-26 14:22:55+00:00
# 722657  a1342206e192709a405485dbe2e647d5c4005d20 2005-04-26 14:19:05+00:00
# 722667  ab2fd30b668b1687a9ca9e9ea0b60145deeafe84 2005-04-25 23:19:32+00:00
# 722721  cf025109e879294f4c6aecf94de1e7b592a9fb07 2005-04-25 14:42:22+00:00
# 722777  21b7ef0c6c62a14bc8e1c8c0af4e1f0ba3a56d66 2005-04-22 17:18:06+00:00
# 722812  8d134db051134c38ae6bf36034403c7da7f0e3da 2005-04-21 21:02:34+00:00
# 722821  6d9c5d94d39a09d9b112613f0bfdb9af0e6dc253 2005-04-21 14:36:42+00:00
# 722847  9f6c6fc505560465be0964eb4da1b6ca97bd3951 2005-04-19 20:14:28+00:00
# 722848  c3c661932cd53582c5b03692b99649300977248a 2005-04-19 20:12:03+00:00
# 722849  c79bea07ec4d3ef087962699fe8b2f6dc5ca7754 2005-04-19 14:31:40+00:00
# 722850  a9e4820c4c170b3df0d2185f7b4130b0b2daed2c 2005-04-19 14:28:57+00:00
# 722879  c0698f2f6e4839ce9463ce731c892993215ea067 2005-04-19 01:55:09+00:00
# 722905  7f907d7486f2519c2ff1493bfbcdc36dcacd85b7 2005-04-18 23:25:10+00:00
# 722908  0b2cad2f30d0353f2576b1a2207c0792ba713157 2005-04-18 21:25:40+00:00
# 722922  c46f2ffb9e7fce7208c2639790e1ade42e00b146 2005-04-18 18:45:00+00:00
# 722944  a4e884a311893b476893739901bed382cd62b4fe 2005-04-17 21:47:24+00:00
# 722945  ce1dc02f76432a46db149241e015a4f782974623 2005-04-17 20:30:46+00:00
# 723163  1da177e4c3f41524e886b7f1b8a0c1fc7321cac2 2005-04-16 22:20:36+00:00
#
#             author_name                     author_email  \
# 26         Rodrigo Vivi           rodrigo.vivi@intel.com
# 72          Zhenyu Wang          zhenyuw@linux.intel.com
# 80         Rodrigo Vivi           rodrigo.vivi@intel.com
# 124        Rodrigo Vivi           rodrigo.vivi@intel.com
# 136         Dave Airlie               airlied@redhat.com
# 137         Dave Airlie               airlied@redhat.com
# 142         Dave Airlie               airlied@redhat.com
# 355        Rodrigo Vivi           rodrigo.vivi@intel.com
# 391         Dave Airlie               airlied@redhat.com
# 488     Gustavo Padovan    gustavo.padovan@collabora.com
# 513         Dave Airlie               airlied@redhat.com
# 514         Dave Airlie               airlied@redhat.com
# 516      Linus Torvalds    torvalds@linux-foundation.org
# 517      Linus Torvalds    torvalds@linux-foundation.org
# 518      Linus Torvalds    torvalds@linux-foundation.org
# 519        Wolfram Sang                wsa@the-dreams.de
# 521      Linus Torvalds    torvalds@linux-foundation.org
# 522      Linus Torvalds    torvalds@linux-foundation.org
# 523      Linus Torvalds    torvalds@linux-foundation.org
# 524      Linus Torvalds    torvalds@linux-foundation.org
# 525      Palmer Dabbelt                palmer@sifive.com
# 526      Palmer Dabbelt                palmer@sifive.com
# 527      Palmer Dabbelt                palmer@sifive.com
# 528      Palmer Dabbelt                palmer@sifive.com
# 529      Palmer Dabbelt                palmer@sifive.com
# 543      Linus Torvalds    torvalds@linux-foundation.org
# 544      Linus Torvalds    torvalds@linux-foundation.org
# 545      Linus Torvalds    torvalds@linux-foundation.org
# 546      Linus Torvalds    torvalds@linux-foundation.org
# 549      Linus Torvalds    torvalds@linux-foundation.org
# ...                 ...                              ...
# 722234   Linus Torvalds         torvalds@ppc970.osdl.org
# 722266   Linus Torvalds         torvalds@ppc970.osdl.org
# 722281   Linus Torvalds         torvalds@ppc970.osdl.org
# 722336  David Woodhouse    dwmw2@shinybook.infradead.org
# 722529   Linus Torvalds         torvalds@ppc970.osdl.org
# 722533   Linus Torvalds         torvalds@ppc970.osdl.org
# 722540   Linus Torvalds         torvalds@ppc970.osdl.org
# 722541   Linus Torvalds         torvalds@ppc970.osdl.org
# 722596   Linus Torvalds         torvalds@ppc970.osdl.org
# 722630   Linus Torvalds         torvalds@ppc970.osdl.org
# 722636   Linus Torvalds         torvalds@ppc970.osdl.org
# 722637   Linus Torvalds         torvalds@ppc970.osdl.org
# 722651   Linus Torvalds         torvalds@ppc970.osdl.org
# 722657   Linus Torvalds         torvalds@ppc970.osdl.org
# 722667   Linus Torvalds         torvalds@ppc970.osdl.org
# 722721   Linus Torvalds         torvalds@ppc970.osdl.org
# 722777   Linus Torvalds         torvalds@ppc970.osdl.org
# 722812   Linus Torvalds         torvalds@ppc970.osdl.org
# 722821   Linus Torvalds         torvalds@ppc970.osdl.org
# 722847   Linus Torvalds  torvalds@ppc970.osdl.org.(none)
# 722848   Linus Torvalds  torvalds@ppc970.osdl.org.(none)
# 722849   Linus Torvalds  torvalds@ppc970.osdl.org.(none)
# 722850   Linus Torvalds  torvalds@ppc970.osdl.org.(none)
# 722879  James Bottomley                     jejb@titanic
# 722905   Linus Torvalds         torvalds@ppc970.osdl.org
# 722908   Linus Torvalds         torvalds@ppc970.osdl.org
# 722922  James Bottomley                     jejb@titanic
# 722944   Linus Torvalds         torvalds@ppc970.osdl.org
# 722945   Linus Torvalds         torvalds@ppc970.osdl.org
# 723163   Linus Torvalds         torvalds@ppc970.osdl.org
#
#               committed_datetime   committer_name  \
# 26     2017-12-22 18:13:23+00:00     Rodrigo Vivi
# 72     2017-12-18 08:29:37+00:00      Zhenyu Wang
# 80     2017-12-14 18:57:41+00:00     Rodrigo Vivi
# 124    2017-12-08 18:15:30+00:00     Rodrigo Vivi
# 136    2017-12-07 22:41:22+00:00      Dave Airlie
# 137    2017-12-07 22:15:54+00:00      Dave Airlie
# 142    2017-12-06 20:28:22+00:00      Dave Airlie
# 355    2017-12-06 00:46:14+00:00     Rodrigo Vivi
# 391    2017-12-05 00:34:46+00:00      Dave Airlie
# 488    2017-12-04 18:04:45+00:00  Gustavo Padovan
# 513    2017-12-04 00:56:53+00:00      Dave Airlie
# 514    2017-12-03 19:42:49+00:00      Dave Airlie
# 516    2017-12-03 15:51:08+00:00   Linus Torvalds
# 517    2017-12-03 15:48:24+00:00   Linus Torvalds
# 518    2017-12-03 15:46:16+00:00   Linus Torvalds
# 519    2017-12-03 14:55:20+00:00     Wolfram Sang
# 521    2017-12-02 01:04:20+00:00   Linus Torvalds
# 522    2017-12-02 01:00:19+00:00   Linus Torvalds
# 523    2017-12-02 00:39:12+00:00   Linus Torvalds
# 524    2017-12-02 00:37:03+00:00   Linus Torvalds
# 525    2017-12-01 21:31:31+00:00   Palmer Dabbelt
# 526    2017-12-01 21:16:15+00:00   Palmer Dabbelt
# 527    2017-12-01 21:14:36+00:00   Palmer Dabbelt
# 528    2017-12-01 21:12:10+00:00   Palmer Dabbelt
# 529    2017-12-01 21:10:42+00:00   Palmer Dabbelt
# 543    2017-12-01 13:40:17+00:00   Linus Torvalds
# 544    2017-12-01 13:36:27+00:00   Linus Torvalds
# 545    2017-12-01 13:14:22+00:00   Linus Torvalds
# 546    2017-12-01 13:10:09+00:00   Linus Torvalds
# 549    2017-12-01 13:05:45+00:00   Linus Torvalds
# ...                          ...              ...
# 722234 2005-05-04 14:06:38+00:00   Linus Torvalds
# 722266 2005-05-04 00:24:08+00:00   Linus Torvalds
# 722281 2005-05-03 22:27:24+00:00   Linus Torvalds
# 722336 2005-05-03 07:14:09+00:00  David Woodhouse
# 722529 2005-04-30 22:42:33+00:00   Linus Torvalds
# 722533 2005-04-30 20:34:21+00:00   Linus Torvalds
# 722540 2005-04-29 22:08:34+00:00   Linus Torvalds
# 722541 2005-04-29 22:06:00+00:00   Linus Torvalds
# 722596 2005-04-28 23:09:57+00:00   Linus Torvalds
# 722630 2005-04-27 17:05:42+00:00   Linus Torvalds
# 722636 2005-04-26 16:02:40+00:00   Linus Torvalds
# 722637 2005-04-26 15:58:22+00:00   Linus Torvalds
# 722651 2005-04-26 14:22:55+00:00   Linus Torvalds
# 722657 2005-04-26 14:19:05+00:00   Linus Torvalds
# 722667 2005-04-25 23:19:32+00:00   Linus Torvalds
# 722721 2005-04-25 14:42:22+00:00   Linus Torvalds
# 722777 2005-04-22 17:18:06+00:00   Linus Torvalds
# 722812 2005-04-21 21:02:34+00:00   Linus Torvalds
# 722821 2005-04-21 14:36:42+00:00   Linus Torvalds
# 722847 2005-04-19 20:14:28+00:00   Linus Torvalds
# 722848 2005-04-19 20:12:03+00:00   Linus Torvalds
# 722849 2005-04-19 14:31:40+00:00   Linus Torvalds
# 722850 2005-04-19 14:28:57+00:00   Linus Torvalds
# 722879 2005-04-19 01:55:09+00:00  James Bottomley
# 722905 2005-04-18 23:25:10+00:00   Linus Torvalds
# 722908 2005-04-18 21:25:40+00:00   Linus Torvalds
# 722922 2005-04-18 18:45:00+00:00  James Bottomley
# 722944 2005-04-17 21:47:24+00:00   Linus Torvalds
# 722945 2005-04-17 20:30:46+00:00   Linus Torvalds
# 723163 2005-04-16 22:20:36+00:00   Linus Torvalds
#
#                         committer_email  \
# 26               rodrigo.vivi@intel.com
# 72              zhenyuw@linux.intel.com
# 80               rodrigo.vivi@intel.com
# 124              rodrigo.vivi@intel.com
# 136                  airlied@redhat.com
# 137                  airlied@redhat.com
# 142                  airlied@redhat.com
# 355              rodrigo.vivi@intel.com
# 391                  airlied@redhat.com
# 488       gustavo.padovan@collabora.com
# 513                  airlied@redhat.com
# 514                  airlied@redhat.com
# 516       torvalds@linux-foundation.org
# 517       torvalds@linux-foundation.org
# 518       torvalds@linux-foundation.org
# 519                   wsa@the-dreams.de
# 521       torvalds@linux-foundation.org
# 522       torvalds@linux-foundation.org
# 523       torvalds@linux-foundation.org
# 524       torvalds@linux-foundation.org
# 525                   palmer@sifive.com
# 526                   palmer@sifive.com
# 527                   palmer@sifive.com
# 528                   palmer@sifive.com
# 529                   palmer@sifive.com
# 543       torvalds@linux-foundation.org
# 544       torvalds@linux-foundation.org
# 545       torvalds@linux-foundation.org
# 546       torvalds@linux-foundation.org
# 549       torvalds@linux-foundation.org
# ...                                 ...
# 722234         torvalds@ppc970.osdl.org
# 722266         torvalds@ppc970.osdl.org
# 722281         torvalds@ppc970.osdl.org
# 722336    dwmw2@shinybook.infradead.org
# 722529         torvalds@ppc970.osdl.org
# 722533         torvalds@ppc970.osdl.org
# 722540         torvalds@ppc970.osdl.org
# 722541         torvalds@ppc970.osdl.org
# 722596         torvalds@ppc970.osdl.org
# 722630         torvalds@ppc970.osdl.org
# 722636         torvalds@ppc970.osdl.org
# 722637         torvalds@ppc970.osdl.org
# 722651         torvalds@ppc970.osdl.org
# 722657         torvalds@ppc970.osdl.org
# 722667         torvalds@ppc970.osdl.org
# 722721         torvalds@ppc970.osdl.org
# 722777         torvalds@ppc970.osdl.org
# 722812         torvalds@ppc970.osdl.org
# 722821         torvalds@ppc970.osdl.org
# 722847  torvalds@ppc970.osdl.org.(none)
# 722848  torvalds@ppc970.osdl.org.(none)
# 722849  torvalds@ppc970.osdl.org.(none)
# 722850  torvalds@ppc970.osdl.org.(none)
# 722879                     jejb@titanic
# 722905         torvalds@ppc970.osdl.org
# 722908         torvalds@ppc970.osdl.org
# 722922                     jejb@titanic
# 722944         torvalds@ppc970.osdl.org
# 722945         torvalds@ppc970.osdl.org
# 723163         torvalds@ppc970.osdl.org
#
#                                                   summary  \
# 26      Merge tag 'gvt-next-2017-12-22' of https://git...
# 72      Merge tag 'drm-intel-next-2017-12-14' into gvt...
# 80      Merge tag 'gvt-next-2017-12-14' of https://git...
# 124     Merge airlied/drm-next into drm-intel-next-queued
# 136     Merge tag 'drm-intel-next-2017-12-01' of git:/...
# 137     Merge tag 'drm-misc-next-2017-12-07' of git://...
# 142     Merge branch 'drm-next-4.16' of git://people.f...
# 355     Merge tag 'gvt-next-2017-12-05' of https://git...
# 391     Merge branch 'drm/next/du' of git://linuxtv.or...
# 488              Merge arlied/drm-next into drm-misc-next
# 513     Merge tag 'drm-intel-next-2017-11-17-1' of git...
# 514     Merge tag 'drm-misc-next-2017-11-30' of git://...
# 516     Merge branch 'fixes' of git://git.armlinux.org...
# 517     Merge branch 'i2c/for-current' of git://git.ke...
# 518     Merge tag 'hwmon-for-linus-v4.15-rc2' of git:/...
# 519     Merge tag 'at24-4.15-fixes-for-wolfram' of git...
# 521     Merge tag 'nfs-for-4.15-2' of git://git.linux-...
# 522     Merge tag 'xfs-4.15-fixes-4' of git://git.kern...
# 523     Merge tag 'riscv-for-linus-4.15-rc2_cleanups' ...
# 524     Merge tag 'arm64-fixes' of git://git.kernel.or...
# 525            RISC-V: Fixes for clean allmodconfig build
# 526                        move libgcc.h to include/linux
# 527     RISC-V: __io_writes should respect the length ...
# 528                          RISC-V: User-Visible Changes
# 529                                RISC-V Atomic Cleanups
# 543     Merge tag 'powerpc-4.15-3' of git://git.kernel...
# 544     Merge tag 'afs-fixes-20171201' of git://git.ke...
# 545     Merge tag 'mmc-v4.15-2' of git://git.kernel.or...
# 546     Merge tag 'drm-fixes-for-v4.15-rc2' of git://p...
# 549     Merge branch 'for-linus' of git://git.kernel.d...
# ...                                                   ...
# 722234  Merge of rsync://rsync.kernel.org/pub/scm/linu...
# 722266  Merge of rsync://rsync.kernel.org/pub/scm/linu...
# 722281  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722336  Merge with master.kernel.org:/pub/scm/linux/ke...
# 722529  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722533  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722540  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722541  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722596  Automatic merge of master.kernel.org:/home/rmk...
# 722630  Automatic merge of rsync://rsync.kernel.org/pu...
# 722636  Automatic merge of kernel.org:/home/rmk/linux-...
# 722637  Automatic merge of kernel.org:/home/rmk/linux-...
# 722651  Automatic merge of rsync://rsync.kernel.org/pu...
# 722657  Automatic merge of rsync://rsync.kernel.org/pu...
# 722667  Automated merge of kernel.org:/home/rmk/linux-...
# 722721  Automatic merge of rsync://rsync.kernel.org/pu...
# 722777  Merge rsync://rsync.kernel.org/pub/scm/linux/k...
# 722812  Merge rsync://rsync.kernel.org/pub/scm/linux/k...
# 722821  Merge rsync://rsync.kernel.org/pub/linux/kerne...
# 722847  Merge with kernel.org:/pub/scm/linux/kernel/gi...
# 722848  Merge with kernel.org:/pub/scm/linux/kernel/gi...
# 722849  Merge master.kernel.org:/pub/scm/linux/kernel/...
# 722850  Merge with Greg's USB tree at kernel.org:/pub/...
# 722879                    fully merge up to scsi-misc-2.6
# 722905  Merge with master.kernel.org:/home/rmk/linux-2...
# 722908              Merge SCSI tree from James Bottomley.
# 722922                      merge by hand (scsi_device.h)
# 722944  Merge with master.kernel.org:/home/rmk/linux-2...
# 722945  Fix up some file mode differences due to the n...
# 723163                                   Linux-2.6.12-rc2
#
#                                                   message files
# 26      Merge tag 'gvt-next-2017-12-22' of https://git...
# 72      Merge tag 'drm-intel-next-2017-12-14' into gvt...
# 80      Merge tag 'gvt-next-2017-12-14' of https://git...
# 124     Merge airlied/drm-next into drm-intel-next-que...
# 136     Merge tag 'drm-intel-next-2017-12-01' of git:/...
# 137     Merge tag 'drm-misc-next-2017-12-07' of git://...
# 142     Merge branch 'drm-next-4.16' of git://people.f...
# 355     Merge tag 'gvt-next-2017-12-05' of https://git...
# 391     Merge branch 'drm/next/du' of git://linuxtv.or...
# 488     Merge arlied/drm-next into drm-misc-next\n\nWe...
# 513     Merge tag 'drm-intel-next-2017-11-17-1' of git...
# 514     Merge tag 'drm-misc-next-2017-11-30' of git://...
# 516     Merge branch 'fixes' of git://git.armlinux.org...
# 517     Merge branch 'i2c/for-current' of git://git.ke...
# 518     Merge tag 'hwmon-for-linus-v4.15-rc2' of git:/...
# 519     Merge tag 'at24-4.15-fixes-for-wolfram' of git...
# 521     Merge tag 'nfs-for-4.15-2' of git://git.linux-...
# 522     Merge tag 'xfs-4.15-fixes-4' of git://git.kern...
# 523     Merge tag 'riscv-for-linus-4.15-rc2_cleanups' ...
# 524     Merge tag 'arm64-fixes' of git://git.kernel.or...
# 525     RISC-V: Fixes for clean allmodconfig build\n\n...
# 526                      move libgcc.h to include/linux\n
# 527     RISC-V: __io_writes should respect the length ...
# 528     RISC-V: User-Visible Changes\n\nThis merge con...
# 529     RISC-V Atomic Cleanups\n\nThis patch set is th...
# 543     Merge tag 'powerpc-4.15-3' of git://git.kernel...
# 544     Merge tag 'afs-fixes-20171201' of git://git.ke...
# 545     Merge tag 'mmc-v4.15-2' of git://git.kernel.or...
# 546     Merge tag 'drm-fixes-for-v4.15-rc2' of git://p...
# 549     Merge branch 'for-linus' of git://git.kernel.d...
# ...                                                   ...   ...
# 722234  Merge of rsync://rsync.kernel.org/pub/scm/linu...
# 722266  Merge of rsync://rsync.kernel.org/pub/scm/linu...
# 722281  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722336  Merge with master.kernel.org:/pub/scm/linux/ke...
# 722529  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722533  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722540  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722541  Merge of master.kernel.org:/home/rmk/linux-2.6...
# 722596  Automatic merge of master.kernel.org:/home/rmk...
# 722630  Automatic merge of rsync://rsync.kernel.org/pu...
# 722636  Automatic merge of kernel.org:/home/rmk/linux-...
# 722637  Automatic merge of kernel.org:/home/rmk/linux-...
# 722651  Automatic merge of rsync://rsync.kernel.org/pu...
# 722657  Automatic merge of rsync://rsync.kernel.org/pu...
# 722667  Automated merge of kernel.org:/home/rmk/linux-...
# 722721  Automatic merge of rsync://rsync.kernel.org/pu...
# 722777  Merge rsync://rsync.kernel.org/pub/scm/linux/k...
# 722812  Merge rsync://rsync.kernel.org/pub/scm/linux/k...
# 722821  Merge rsync://rsync.kernel.org/pub/linux/kerne...
# 722847  Merge with kernel.org:/pub/scm/linux/kernel/gi...
# 722848  Merge with kernel.org:/pub/scm/linux/kernel/gi...
# 722849  Merge master.kernel.org:/pub/scm/linux/kernel/...
# 722850  Merge with Greg's USB tree at kernel.org:/pub/...
# 722879                  fully merge up to scsi-misc-2.6\n
# 722905  Merge with master.kernel.org:/home/rmk/linux-2...
# 722908  Merge SCSI tree from James Bottomley.\n\nDone ...
# 722922                    merge by hand (scsi_device.h)\n
# 722944  Merge with master.kernel.org:/home/rmk/linux-2...
# 722945  Fix up some file mode differences due to the n...
# 723163  Linux-2.6.12-rc2\n\nInitial git repository bui...
#
# [52746 rows x 10 columns]
