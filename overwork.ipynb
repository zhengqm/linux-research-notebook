# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
commits = pd.read_pickle("commits.pkl")

# %%
commits.committer_name.value_counts()
# Out:
# Linus Torvalds                  71147
# Greg Kroah-Hartman              67758
# David S. Miller                 67247
# Mauro Carvalho Chehab           26911
# Ingo Molnar                     21830
# Mark Brown                      20676
# John W. Linville                18882
# Daniel Vetter                    9814
# Takashi Iwai                     9628
# James Bottomley                  9152
# Russell King                     8886
# Jeff Garzik                      7820
# Ralf Baechle                     7655
# Rafael J. Wysocki                7596
# Arnaldo Carvalho de Melo         6954
# Dave Airlie                      6740
# Jens Axboe                       6482
# Al Viro                          5927
# Thomas Gleixner                  5917
# Linus Walleij                    5783
# Alex Deucher                     5494
# Trond Myklebust                  5008
# Kalle Valo                       4993
# Tony Lindgren                    4781
# Paul Mundt                       4642
# Felipe Balbi                     4622
# Dmitry Torokhov                  4523
# Herbert Xu                       4368
# Paul Mackerras                   4303
# Len Brown                        4299
#                                 ...
# Jan-Benedict Glaw                   2
# Andrzej Hajda                       2
# Serge E. Hallyn                     2
# hch@lst.de                          2
# David Rientjes                      2
# Romieu Francois                     2
# Ricardo Neri                        2
# Nicholas A. Bellinger               2
# Artem B. Bityutskiy                 2
# Szymon Janc                         2
# Tim Gardner                         2
# Stefan Wahren                       2
# Gertjan van Wingerde                1
# Damien Lespiau                      1
# James E.J. Bottomley                1
# Auke-jan Kok                        1
# Cyrill Gorcunov                     1
# ohad                                1
# Allen Hubbe                         1
# John Linn                           1
# Franc�ois Romieu                    1
# Daniel Thompson                     1
# Hans Ulli Kroll                     1
# Steven French                       1
# James                               1
# Timothy Shimmin                     1
# Blagovest Borisov Kolenichev        1
# ldewangan                           1
# Mike Rapoport                       1
# Jiang Liu                           1
# Name: committer_name, Length: 630, dtype: int64

# %%
commits[commits.committed_datetime >= "20160101"].committer_name.value_counts()
# Out:
# David S. Miller                 15698
# Greg Kroah-Hartman              12205
# Linus Torvalds                   8240
# Mauro Carvalho Chehab            4286
# Mark Brown                       4168
# Ingo Molnar                      3791
# Alex Deucher                     3122
# Doug Ledford                     2444
# Kalle Valo                       2350
# Martin K. Petersen               2330
# Arnaldo Carvalho de Melo         2157
# Michael Ellerman                 2116
# Rafael J. Wysocki                2078
# Linus Walleij                    1993
# Jens Axboe                       1938
# Daniel Vetter                    1834
# Chris Wilson                     1478
# Bjorn Helgaas                    1406
# Thomas Gleixner                  1381
# Herbert Xu                       1376
# Jonathan Cameron                 1371
# Takashi Iwai                     1288
# Ulf Hansson                      1248
# Ralf Baechle                     1171
# Jeff Kirsher                     1084
# Felipe Balbi                      975
# David Sterba                      967
# Simon Horman                      950
# Al Viro                           943
# Stephen Boyd                      848
#                                 ...
# Markus Pargmann                     7
# Hans-Christian Egtvedt              6
# Alan Tull                           6
# Jisheng Zhang                       5
# Patrik Jakobsson                    5
# Stefan Schmidt                      5
# Pavel Shilovsky                     5
# Tyler Hicks                         5
# Stefan Richter                      5
# Jon Medhurst                        4
# Zhi Wang                            4
# Antoine Tenart                      4
# Akash Choudhari                     4
# Jeffrey Carlyle                     3
# Alexander Sverdlin                  3
# Eric Wheeler                        3
# Mark Salter                         3
# Marek Vasut                         3
# Sylvain Lemieux                     3
# Andy Lutomirski                     2
# Stefan Wahren                       2
# Andrzej Hajda                       2
# Szymon Janc                         2
# Christian König                     1
# root                                1
# Blagovest Borisov Kolenichev        1
# Benjamin LaHaise                    1
# ldewangan                           1
# Daniel Thompson                     1
# Eric Van Hensbergen                 1
# Name: committer_name, Length: 309, dtype: int64

# %%
s1 = commits[commits.committer_name == "Greg Kroah-Hartman"]
g = s1.groupby(s1.committed_datetime.map(lambda t: t.year))
for i, df in g:
    plt.figure(facecolor="white")
    s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
    print i, s[8:].sum()
    s.sort_index().plot.bar()
    plt.show()
# Out:
# 2005 0.0456790123457
# 2006 0.104777415852
# 2007 0.109022556391
# 2008 0.0783898305085
# 2009 0.048087431694
# 2010 0.176339782077
# 2011 0.190604478868
# 2012 0.258028327023
# 2013 0.263850331925
# 2014 0.270535463975
# 2015 0.44367330517
# 2016 0.540754958413
# 2017 0.326651480638

# %%
s1 = commits[commits.committer_name == "David S. Miller"]
g = s1.groupby(s1.committed_datetime.map(lambda t: t.year))
for i, df in g:
    plt.figure(facecolor="white")
    s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
    print i, s[8:].sum()
    s.sort_index().plot.bar()
    plt.show()
# Out:
# 2005 0.164739884393
# 2006 0.200642054575
# 2007 0.242433323344
# 2008 0.321116928447
# 2009 0.437115707099
# 2010 0.467573427952
# 2011 0.343910405973
# 2012 0.389153619242
# 2013 0.344378055405
# 2014 0.311354182715
# 2015 0.411351667642
# 2016 0.406339341206
# 2017 0.330066640533

# %%
s1 = commits[commits.committer_name == "Linus Torvalds"]
g = s1.groupby(s1.committed_datetime.map(lambda t: t.year))
for i, df in g:
    plt.figure(facecolor="white")
    s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
    print i, s[8:].sum()
    s.sort_index().plot.bar()
    plt.show()
# Out:
# 2005 0.282833020638
# 2006 0.231326584976
# 2007 0.200404312668
# 2008 0.186584531143
# 2009 0.237039622971
# 2010 0.266230620155
# 2011 0.320314419062
# 2012 0.259283246978
# 2013 0.215539858729
# 2014 0.208733806937
# 2015 0.291951219512
# 2016 0.215573944409
# 2017 0.23390983839

# %%
s1 = commits[commits.committer_name == "Mark Brown"]
g = s1.groupby(s1.committed_datetime.map(lambda t: t.year))
for i, df in g:
    plt.figure(facecolor="white")
    s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
    print i, s[8:].sum()
    s.sort_index().plot.bar()
    plt.show()
# Out:
# 2008 0.124087591241
# 2009 0.326579261025
# 2010 0.246696035242
# 2011 0.403669724771
# 2012 0.447726389429
# 2013 0.300647820966
# 2014 0.375173949346
# 2015 0.291679650982
# 2016 0.278322226578
# 2017 0.195423623995

# %%
s1 = commits[commits.committer_name == "Michael Ellerman"]
g = s1.groupby(s1.committed_datetime.map(lambda t: t.year))
for i, df in g:
    plt.figure()
    s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
    print i, s[8:].sum()
    s.sort_index().plot.bar()
# Out:
# 2005 nan
# 2013 nan
# 2014 0.194331983806
# 2015 0.200553250346
# 2016 0.299338999056
# 2017 0.210028382214

# %%
s1 = commits[commits.committer_name == "Doug Ledford"]
g = s1.groupby(s1.committed_datetime.map(lambda t: t.year))
for i, df in g:
    plt.figure()
    s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
    print i, s[8:].sum()
    s.sort_index().plot.bar()
# Out:
# 2015 0.207446808511
# 2016 0.198679867987
# 2017 0.153928955867

# %%
s1 = commits[commits.committer_name == "Daniel Vetter"]
g = s1.groupby(s1.committed_datetime.map(lambda t: t.year))
for i, df in g:
    plt.figure()
    s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
    print i, s[8:].sum()
    s.sort_index().plot.bar()
# Out:
# 2011 nan
# 2012 0.320644216691
# 2013 0.419371196755
# 2014 0.329923273657
# 2015 0.288091068301
# 2016 0.275459098497
# 2017 0.22641509434

# %% [markdown]
# # by hour!

# %%
# sum stat

# %%
result = {}
for year in range(2006, 2017):
    subset = commits[commits.committed_datetime.map(lambda t: t.year) == year]
    committers = subset.committer_name.value_counts()[:60]
    arr = []
    for committer in committers.index:
        df = subset[subset.committer_name == committer]
        s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
        if len(s) > 8:
            arr.append(s[8:].sum())
        else:
            arr.append(0.0)
    result[year] = arr

# %%
result_df = pd.DataFrame(result)

# %%
plt.figure(facecolor="white")
result_df.plot.box()

# %%
plt.figure(facecolor="white")
result_df.mean().plot()

# %%
plt.figure(facecolor="white")
result_df.median().plot()

# %%
# contiguous version

# %%
def overwork_ratio(s):
    temp = {}
    for i in range(24):
        if i in s:
            temp[i] = s[i]
        else:
            temp[i] = 0
    for i in range(24, 48):
        temp[i] = temp[i-24]
    s = pd.Series(temp)
    s = s.sort_index()
    return 1 - s.rolling(window=8).sum().max()

# %%
result = {}
for year in range(2006, 2017):
    subset = commits[commits.committed_datetime.map(lambda t: t.year) == year]
    committers = subset.committer_name.value_counts()[:60]
    arr = []
    for committer in committers.index:
        df = subset[subset.committer_name == committer]
        s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
        arr.append(overwork_ratio(s))
    result[year] = arr

# %%
result_df = pd.DataFrame(result)

# %%
plt.figure(facecolor="white")
result_df.plot.box()

# %%
plt.figure(facecolor="white")
result_df.mean().plot()

# %%
plt.figure(facecolor="white")
result_df.median().plot()

# %%
# entropy stat

# %%
result = {}
for year in range(2006, 2017):
    subset = commits[commits.committed_datetime.map(lambda t: t.year) == year]
    committers = subset.committer_name.value_counts()[:50]
    arr = []
    for committer in committers.index:
        df = subset[subset.committer_name == committer]
        s = df.committed_datetime.map(lambda t: t.hour).value_counts(normalize=True)
        entropy = sum(-np.log(s) * s)
        arr.append(entropy)
    result[year] = arr

# %%
result_df = pd.DataFrame(result)

# %%
plt.figure(facecolor="white")
result_df.mean().plot()

# %%
plt.figure(facecolor="white")
result_df.median().plot()

# %%
result_df.plot.box()

# %% [markdown]
# # by weekday

# %%
result = {}
for year in range(2006, 2017):
    subset = commits[commits.committed_datetime.map(lambda t: t.year) == year]
    committers = subset.committer_name.value_counts()[:50]
    arr = []
    for committer in committers.index:
        df = subset[subset.committer_name == committer]
        s = df.committed_datetime.map(lambda t: t.weekday()).value_counts(normalize=True)
        entropy = sum(-np.log(s) * s)
        arr.append(entropy)
    result[year] = arr

# %%
result_df = pd.DataFrame(result)

# %%
plt.figure(facecolor="white")
result_df.mean().plot()

# %%
plt.figure(facecolor="white")
result_df.median().plot()

# %%
result_df.plot.box()

# %%
# 24 * 7

# %%
result = {}
for year in range(2006, 2017):
    subset = commits[commits.committed_datetime.map(lambda t: t.year) == year]
    committers = subset.committer_name.value_counts()[:50]
    arr = []
    for committer in committers.index:
        df = subset[subset.committer_name == committer]
        s = df.committed_datetime.map(lambda t: (t.weekday(), t.hour)).value_counts(normalize=True)
        if len(s) > 40:
            arr.append(s[40:].sum())
        else:
            arr.append(0.0)
    result[year] = arr

# %%
result_df = pd.DataFrame(result)

# %%
result_df.mean().plot()

# %%
result_df.median().plot()

# %%
result = {}
for year in range(2006, 2017):
    subset = commits[commits.committed_datetime.map(lambda t: t.year) == year]
    committers = subset.committer_name.value_counts()[:50]
    arr = []
    for committer in committers.index:
        df = subset[subset.committer_name == committer]
        s = df.committed_datetime.map(lambda t: (t.weekday(), t.hour)).value_counts(normalize=True)
        entropy = sum(-np.log(s) * s)
        arr.append(entropy)
    result[year] = arr

# %%
result_df = pd.DataFrame(result)

# %%
plt.figure(facecolor="white")
result_df.mean().plot()

# %%
plt.figure(facecolor="white")
result_df.median().plot()
